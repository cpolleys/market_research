# %%
from pipeline import run, run_landscape
import os

main_dir = 'C:\\Users\\chris\\Documents\\personal_projects\\market_research'
save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

#conditions = [
#        "ST Elevation Myocardial Infarction"
#    ]


run()
#run_landscape(conditions)
# Out:
# SIC 2836: 489 companies
# SIC 2835: 151 companies
# SIC 2834: 1896 companies
# SIC 8731: 181 companies
# SIC 3841: 587 companies
# SIC 3845: 260 companies
# SIC 3826: 108 companies
# SIC 3827: 43 companies
# Total unique CIKs: 3715
# SEC universe: 904 companies with valid tickers
# [1/911] icu medical: 0 new snapshots, 3 unchanged
# [2/911] polyrizon: 0 new snapshots, 1 unchanged
# [3/911] fate therapeutics: 0 new snapshots, 25 unchanged
# [4/911] medtronic: 1 new snapshots, 1652 unchanged
# [5/911] tenax therapeutics: 0 new snapshots, 9 unchanged
# [6/911] lyell immunopharma: 0 new snapshots, 7 unchanged
# [7/911] edap tms: 0 new snapshots, 12 unchanged
# [8/911] propanc biopharma: 0 new snapshots, 0 unchanged
# [9/911] precipio: 0 new snapshots, 0 unchanged
# [10/911] corvus pharmaceuticals: 0 new snapshots, 10 unchanged
# [11/911] kodiak sciences: 0 new snapshots, 11 unchanged
# [12/911] rockwell medical: 0 new snapshots, 20 unchanged
# ...
