# %%
import requests, json

nct_id = 'NCT06728059'
r = requests.get(f'https://clinicaltrials.gov/api/v2/studies/{nct_id}')
data = r.json()

print('Has results:', data.get('hasResults'))
print(json.dumps(data.get('resultsSection', {}), indent=2))
# Out:
# Has results: True
# {
#   "participantFlowModule": {
#     "recruitmentDetails": "Three participants were determined to be ineligible. One withdrew before randomization.",
#     "groups": [
#       {
#         "id": "FG000",
#         "title": "AIDANET\u2192AIDANET+ BPS_RL",
#         "description": "Group A: AIDANET (Automated Insulin Delivery Adaptive NETwork) followed by AIDANET+ BPS\\_RL during the hotel session\n\nGroup A participants will use the AIDANET system at home for 7 days/6 nights. During the hotel session, they will continue to use the AIDANET system for 18 hours, followed by 18 hours of use of AIDANET+BPS\\_RL.\n\nThey will continue to use AIDANET+ BPS\\_RL system at home for 7 days/6 nights."
#       },
#       {
#         "id": "FG001",
#         "title": "AIDANET+ BPS_RL\u2192AIDANET",
# ...
