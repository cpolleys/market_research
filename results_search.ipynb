# %%
import requests, json

nct_id = 'NCT04540302'
r = requests.get(f'https://clinicaltrials.gov/api/v2/studies/{nct_id}')
data = r.json()

print('Has results:', data.get('hasResults'))
print(json.dumps(data.get('resultsSection', {}), indent=2))
# Out:
# Has results: True
# {
#   "participantFlowModule": {
#     "groups": [
#       {
#         "id": "FG000",
#         "title": "AVF Peripheral Study Treatment Group",
#         "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#       },
#       {
#         "id": "FG001",
#         "title": "AVF Peripheral Control Group",
#         "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#       },
#       {
#         "id": "FG002",
#         "title": "AVG Anastomosis",
#         "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#       }
#     ],
#     "periods": [
#       {
#         "title": "Overall Study",
#         "milestones": [
#           {
#             "type": "STARTED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "122"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "123"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "112"
#               }
#             ]
#           },
#           {
#             "type": "COMPLETED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "81"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "70"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "54"
#               }
#             ]
#           },
#           {
#             "type": "NOT COMPLETED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "41"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "53"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "58"
#               }
#             ]
#           }
#         ],
#         "dropWithdraws": [
#           {
#             "type": "Death",
#             "reasons": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "24"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "25"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "21"
#               }
#             ]
#           },
#           {
#             "type": "Withdrawal by Subject",
#             "reasons": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "3"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "2"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "6"
#               }
#             ]
#           },
#           {
#             "type": "Early termination",
#             "reasons": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "11"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "24"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "28"
#               }
#             ]
#           },
#           {
#             "type": "Lost to Follow-up",
#             "reasons": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "3"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "1"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "3"
#               }
#             ]
#           },
#           {
#             "type": "Discharge Safety Follow-up Only",
#             "reasons": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "0"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "1"
#               },
#               {
#                 "groupId": "FG002",
#                 "numSubjects": "0"
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "baselineCharacteristicsModule": {
#     "groups": [
#       {
#         "id": "BG000",
#         "title": "AVF Peripheral Study Treatment Group",
#         "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#       },
#       {
#         "id": "BG001",
#         "title": "AVF Peripheral Control Group",
#         "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#       },
#       {
#         "id": "BG002",
#         "title": "AVG Anastomosis",
#         "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#       },
#       {
#         "id": "BG003",
#         "title": "Total",
#         "description": "Total of all reporting groups"
#       }
#     ],
#     "denoms": [
#       {
#         "units": "Participants",
#         "counts": [
#           {
#             "groupId": "BG000",
#             "value": "122"
#           },
#           {
#             "groupId": "BG001",
#             "value": "123"
#           },
#           {
#             "groupId": "BG002",
#             "value": "112"
#           },
#           {
#             "groupId": "BG003",
#             "value": "357"
#           }
#         ]
#       }
#     ],
#     "measures": [
#       {
#         "title": "Age, Continuous",
#         "paramType": "MEAN",
#         "dispersionType": "STANDARD_DEVIATION",
#         "unitOfMeasure": "years",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "61.6",
#                     "spread": "13.9"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "60.1",
#                     "spread": "14.5"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "64.1",
#                     "spread": "13.3"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "61.8",
#                     "spread": "13.96"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Sex: Female, Male",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "Female",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "52"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "54"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "61"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "167"
#                   }
#                 ]
#               },
#               {
#                 "title": "Male",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "70"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "69"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "51"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "190"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Ethnicity (NIH/OMB)",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "Hispanic or Latino",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "41"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "37"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "28"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "106"
#                   }
#                 ]
#               },
#               {
#                 "title": "Not Hispanic or Latino",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "81"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "86"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "83"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "250"
#                   }
#                 ]
#               },
#               {
#                 "title": "Unknown or Not Reported",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "1"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "1"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Race (NIH/OMB)",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "calculatePct": false,
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "American Indian or Alaska Native",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "2"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "1"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "3"
#                   }
#                 ]
#               },
#               {
#                 "title": "Asian",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "3"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "6"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "3"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "12"
#                   }
#                 ]
#               },
#               {
#                 "title": "Native Hawaiian or Other Pacific Islander",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "1"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "1"
#                   }
#                 ]
#               },
#               {
#                 "title": "Black or African American",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "47"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "51"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "69"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "167"
#                   }
#                 ]
#               },
#               {
#                 "title": "White",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "65"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "62"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "34"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "161"
#                   }
#                 ]
#               },
#               {
#                 "title": "More than one race",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "4"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "4"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "5"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "13"
#                   }
#                 ]
#               },
#               {
#                 "title": "Unknown or Not Reported",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "0"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Region of Enrollment",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "participants",
#         "classes": [
#           {
#             "title": "Canada",
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "1"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "3"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "4"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "title": "United States",
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "99"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "98"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "85"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "282"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "title": "Brazil",
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "17"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "18"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "17"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "52"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "title": "United Kingdom",
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "5"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "7"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "7"
#                   },
#                   {
#                     "groupId": "BG003",
#                     "value": "19"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "outcomeMeasuresModule": {
#     "outcomeMeasures": [
#       {
#         "type": "PRIMARY",
#         "title": "Subjects Without Any Localized or Systemic Safety Events (Primary Safety Endpoint)",
#         "description": "Percentage of subjects without any localized or systemic safety events through 30 days post-index procedure that affect the access or venous outflow circuit and resulted in reintervention, hospitalization, or death (not including stenosis or thrombosis). Endovascular procedures performed to treat safety events after the index study procedure will be considered surgeries.",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "30 days",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "119"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "121"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "109"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "115"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "115"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "104"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "PRIMARY",
#         "title": "Subjects With Target Lesion Primary Patency (TLPP) (Primary Effectiveness Endpoint:)",
#         "description": "Percentage of subjects with Target Lesion Primary Patency (TLPP) at 6 Months. TLPP is defined as freedom from clinically-driven target lesion revascularization (CD-TLR) or target lesion thrombosis measured through 6 months post-procedure, which is the time interval of uninterrupted patency after study procedure to the next intervention performed on the target lesion or uncorrectable target lesion occlusion.",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "6 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "115"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "114"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "97"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "103"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "71"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "79"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Target Lesion Primary Patency",
#         "description": "Percentage of subjects with Target Lesion Primary Patency (TLPP) at 12 Months. TLPP is defined as freedom from clinically-driven target lesion revascularization (CD-TLR) or target lesion thrombosis measured through 6 months post-procedure, which is the time interval of uninterrupted patency after study procedure to the next intervention performed on the target lesion or uncorrectable target lesion occlusion.",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "12 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "108"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "104"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "88"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "76"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "40"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "51"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Target Lesion Primary Patency",
#         "description": "Percentage of subjects with Target Lesion Primary Patency (TLPP) at 24 Months. TLPP is defined as freedom from clinically-driven target lesion revascularization (CD-TLR) or target lesion thrombosis measured through 6 months post-procedure, which is the time interval of uninterrupted patency after study procedure to the next intervention performed on the target lesion or uncorrectable target lesion occlusion.",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "24 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "93"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "94"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "77"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "42"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "21"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "26"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Assisted Target Lesion Primary Patency (aTLPP)",
#         "description": "Kaplan Meier Estimate Percent Probability of Assisted Target Lesion Primary Patency at 6 months.\n\naTLPP was defined as time to loss of Assisted Primary Patency of the target lesion, which is the time from post-procedure until uncorrectable target lesion occlusion. Participants who did not experience loss of aTLPP were censored at the time of last available follow-up.",
#         "populationDescription": "Assisted Target Lesion Primary Patency (aTLPP) was analyzed using the Kaplan-Meier method. The reported percentages represent the Kaplan-Meier estimated probability of remaining free from loss of assisted target lesion primary patency at the specified time point. These estimates account for censoring and are not simple proportions of participants experiencing the event.",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "KM estimate (%)",
#         "timeFrame": "6 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "122"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "123"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "112"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "99.1"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "99.1"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "97.1"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Assisted Target Lesion Primary Patency (aTLPP)",
#         "description": "Kaplan Meier Estimate Percent Probability of Assisted Target Lesion Primary Patency at 12 months.\n\naTLPP was defined as time to loss of Assisted Primary Patency of the target lesion, which is the time from post-procedure until uncorrectable target lesion occlusion. Participants who did not experience loss of aTLPP were censored at the time of last available follow-up.",
#         "populationDescription": "Assisted Target Lesion Primary Patency (aTLPP) was analyzed using the Kaplan-Meier method. The reported percentages represent the Kaplan-Meier estimated probability of remaining free from loss of assisted target lesion primary patency at the specified time point. These estimates account for censoring and are not simple proportions of participants experiencing the event.",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "KM estimate (%)",
#         "timeFrame": "12 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "122"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "123"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "112"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "99.1"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "99.1"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "93.4"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Assisted Target Lesion Primary Patency (aTLPP)",
#         "description": "Kaplan Meier Estimate Percent Probability of Assisted Target Lesion Primary Patency at 24 months.\n\naTLPP was defined as time to loss of Assisted Primary Patency of the target lesion, which is the time from post-procedure until uncorrectable target lesion occlusion. Participants who did not experience loss of aTLPP were censored at the time of last available follow-up.",
#         "populationDescription": "Assisted Target Lesion Primary Patency (aTLPP) was analyzed using the Kaplan-Meier method. The reported percentages represent the Kaplan-Meier estimated probability of remaining free from loss of assisted target lesion primary patency at the specified time point. These estimates account for censoring and are not simple proportions of participants experiencing the event.",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "KM estimate (%)",
#         "timeFrame": "24 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "122"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "123"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "112"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "97.9"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "99.1"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "92.0"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Access Circuit Primary Patency (ACPP)",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "6 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "115"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "114"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "100"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "83"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "65"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "68"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Access Circuit Primary Patency (ACPP)",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "12 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "110"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "106"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "92"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "62"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "33"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "31"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Access Circuit Primary Patency (ACPP)",
#         "populationDescription": "Denominators include all subjects who have the indicated event or who have adequate follow-up",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "24 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "99"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "99"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "86"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "27"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "15"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "17"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Post-Procedure Secondary Patency",
#         "description": "Kaplan Meier Estimate Percent Probability of Post-Procedure Secondary Patency at 6 months.\n\nPost-Procedure Secondary Patency was defined as the interval post-procedure until access circuit abandonment. Participants who did not experience loss of Post-Procedure Secondary Patency were censored at the time of last available follow-up.",
#         "populationDescription": "Post-Procedure Secondary Patency was analyzed using the Kaplan-Meier method. The reported percentages represent the Kaplan-Meier estimated probability of remaining free from loss of Post-Procedure Secondary Patency at the specified time point. These estimates account for censoring and are not simple proportions of participants experiencing the event.",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "KM estimate (%)",
#         "timeFrame": "6 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "AVF Peripheral Study Treatment Group",
#             "description": "Subjects randomised to treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           },
#           {
#             "id": "OG001",
#             "title": "AVF Peripheral Control Group",
#             "description": "Subjects randomised to treatment with standard percutaneous transluminal angioplasty (PTA)\n\nPTA: Target lesion treated with standard percutaneous transluminal angioplasty (PTA)"
#           },
#           {
#             "id": "OG002",
#             "title": "AVG Anastomosis",
#             "description": "All subjects in this single arm cohort will receive treatment with the WRAPSODY Endovascular Stent Graft\n\nMerit WRAPSODY Endovascular Stent Graft: Target lesion treated with stent graft placement"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "122"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "123"
#               },
#               {
#                 "groupId": "OG002",
#                 "value": "112"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "100"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "100"
#                   },
#                   {
#                     "groupId": "OG002",
#                     "value": "95.1"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Subjects With Post-Procedure Secondary Patency",
# ...
#           }
#         ]
#       },
#       {
#         "term": "Total occlusion of the vascular access circuit",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Transient ischemic attack (TIA)",
#         "organSystem": "Nervous system disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Urinary tract infection (UTI)",
#         "organSystem": "Renal and urinary disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Vascular access complications",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Ventricular tachycardia",
#         "organSystem": "Cardiac disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Vessel rupture",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Vessel spasm or recoil",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Pain",
#         "organSystem": "General disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 4,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 9,
#             "numAffected": 8,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Dialysis Access Complications",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 4,
#             "numAffected": 2,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 8,
#             "numAffected": 6,
#             "numAtRisk": 112
#           }
#         ]
#       }
#     ],
#     "otherEvents": [
#       {
#         "term": "Anemia",
#         "organSystem": "Blood and lymphatic system disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 2,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 9,
#             "numAffected": 6,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Bacteremia or septicemia",
#         "organSystem": "Infections and infestations",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 5,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 9,
#             "numAffected": 8,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Bleeding complication",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 6,
#             "numAffected": 6,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 6,
#             "numAffected": 6,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Gastro-intestinal bleeding",
#         "organSystem": "Gastrointestinal disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 3,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 3,
#             "numAffected": 2,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 11,
#             "numAffected": 7,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Infection, localized",
#         "organSystem": "Infections and infestations",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 5,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 9,
#             "numAffected": 7,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 11,
#             "numAffected": 8,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Pneumonia",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 6,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 11,
#             "numAffected": 9,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 7,
#             "numAffected": 7,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Pseudoaneurysm",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 7,
#             "numAffected": 6,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Restenosis (non-target lesion)",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 84,
#             "numAffected": 32,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 70,
#             "numAffected": 31,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 84,
#             "numAffected": 33,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Restenosis of treated segment (target lesion)",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 83,
#             "numAffected": 39,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 154,
#             "numAffected": 72,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 39,
#             "numAffected": 22,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "SARS, COVID-19",
#         "organSystem": "Infections and infestations",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 5,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 8,
#             "numAffected": 8,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Sepsis or systemic infection",
#         "organSystem": "Infections and infestations",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 10,
#             "numAffected": 9,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 9,
#             "numAffected": 7,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 8,
#             "numAffected": 7,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Steal syndrome",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 5,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 8,
#             "numAffected": 7,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 7,
#             "numAffected": 7,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Stenosis (non-target)",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 62,
#             "numAffected": 40,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 46,
#             "numAffected": 32,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 84,
#             "numAffected": 39,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Thrombosis",
#         "organSystem": "Vascular disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 11,
#             "numAffected": 10,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 11,
#             "numAffected": 7,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 58,
#             "numAffected": 29,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Pain",
#         "organSystem": "General disorders",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 14,
#             "numAffected": 12,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 12,
#             "numAffected": 9,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 30,
#             "numAffected": 14,
#             "numAtRisk": 112
#           }
#         ]
#       },
#       {
#         "term": "Dialysis Access Complications",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 10,
#             "numAffected": 10,
#             "numAtRisk": 122
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 5,
#             "numAffected": 3,
#             "numAtRisk": 123
#           },
#           {
#             "groupId": "EG002",
#             "numEvents": 11,
#             "numAffected": 9,
#             "numAtRisk": 112
#           }
#         ]
#       }
#     ]
#   },
#   "moreInfoModule": {
#     "certainAgreement": {
#       "piSponsorEmployee": false,
#       "restrictionType": "GT60",
#       "restrictiveAgreement": true
#     },
#     "pointOfContact": {
#       "title": "Pamela DiCamillo",
#       "organization": "Merit Medical Systems, Inc",
#       "email": "pamela.dicamillo@merit.com",
#       "phone": "385-766-9141"
#     }
#   }
# }
