# %%
#from mappings import get_sec_universe

#get_sec_universe()

from scraper import fetch_trials
trials = fetch_trials('modernatx')
print(len(trials))
print(trials[0]['sponsor'])
# Out:
# 138
# ModernaTX, Inc.
