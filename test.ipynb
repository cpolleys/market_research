# %%
from pipeline import run_epidemiology

run_epidemiology()                                          # all conditions in disease_landscape
run_epidemiology("Sickle Cell Disease")                     # specific list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12368/939802557.py in <module>
# ----> 1 from pipeline import run_epidemiology
#       2
#       3 run_epidemiology()                                          # all conditions in disease_landscape
#       4 run_epidemiology("Sickle Cell Disease")                     # specific list
#
# ~\Documents\personal_projects\market_research\pipeline.py in <module>
#      10 from pubmed import get_latest_publication
#      11 from datetime import datetime, date
# ---> 12 from epidemiology import refresh_all_conditions, init_epidemiology_table
#      13
#      14
#
# ~\Documents\personal_projects\market_research\epidemiology.py in <module>
#     318
#     319
# --> 320 def _fuzzy_match(query: str, candidates: list[str], cutoff: float = 0.6) -> str | None:
#     321     """Return the best fuzzy match from a list, or None."""
#     322     q = _normalize(query)
#
# TypeError: unsupported operand type(s) for |: 'type' and 'NoneType'
