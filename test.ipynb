# %%
from mappings import get_sec_universe

get_sec_universe()
# Out:
# SIC 2836: 489 companies
# SIC 2835: 151 companies
# SIC 2830: 0 companies
# SIC 8731: 181 companies
# SIC 3841: 587 companies
# SIC 3845: 260 companies
# SIC 3826: 108 companies
# SIC 3827: 43 companies
# Total unique CIKs: 1819
# SEC universe: 369 companies with valid tickers
# [{'ticker': 'TARA', 'name': 'protara therapeutics'},
#  {'ticker': 'RSMDF', 'name': 'resmed'},
#  {'ticker': 'LXEO', 'name': 'lexeo therapeutics'},
#  {'ticker': 'NOTV', 'name': 'inotiv'},
#  {'ticker': 'GKOS', 'name': 'glaukos'},
#  {'ticker': 'IVVD', 'name': 'invivyd'},
#  {'ticker': 'ANGO', 'name': 'angiodynamics'},
#  {'ticker': 'NMTC', 'name': 'neuroone medical technologies'},
#  {'ticker': 'RGNX', 'name': 'regenxbio'},
#  {'ticker': 'PLSE', 'name': 'pulse biosciences'},
#  {'ticker': 'SOLV', 'name': 'solventum'},
#  {'ticker': 'VYCO', 'name': 'vycor medical'},
#  {'ticker': 'QCLS', 'name': 'q/c technologies'},
#  {'ticker': 'KMTS', 'name': 'kestra medical technologies'},
# ...
