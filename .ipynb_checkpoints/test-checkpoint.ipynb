# %%
import sqlite3
import pandas as pd
import os

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

conn = sqlite3.connect("biotech.db")
pd.read_sql_query("""
    SELECT nct_id, snapshot_date, COUNT(*) as cnt
    FROM trials
    GROUP BY nct_id, snapshot_date
    HAVING cnt > 1
    LIMIT 10
""", conn)
# Out:
#   snapshot_date    cnt
# 0    2026-05-19  51850
# 1    2026-05-20  51152
