# %%
from mappings import get_sec_universe

get_sec_universe()
# Out:
# SIC 2836: 489 companies
# SIC 2835: 151 companies
# SIC 2830: 0 companies
# SIC 8731: 181 companies
# SIC 3841: 587 companies
# SIC 3845: 260 companies
# SIC 3826: 108 companies
# SIC 3827: 43 companies
# Total unique CIKs: 1819
# SEC universe: 369 companies with valid tickers
# [{'ticker': 'ESMC', 'name': 'escalon medical'},
#  {'ticker': 'CLLS', 'name': 'cellectis'},
#  {'ticker': 'DYAI', 'name': 'dyadic international'},
#  {'ticker': 'CLPT', 'name': 'clearpoint neuro'},
#  {'ticker': 'BBNX', 'name': 'beta bionics'},
#  {'ticker': 'FATE', 'name': 'fate therapeutics'},
#  {'ticker': 'SI', 'name': 'shoulder innovations'},
#  {'ticker': 'APGE', 'name': 'apogee therapeutics'},
#  {'ticker': 'TXG', 'name': '10x genomics'},
#  {'ticker': 'NAUT', 'name': 'nautilus biotechnology'},
#  {'ticker': 'AURX', 'name': 'nuo therapeutics'},
#  {'ticker': 'ADMT', 'name': 'adm tronics unlimited'},
#  {'ticker': 'BEAM', 'name': 'beam therapeutics'},
# ...
