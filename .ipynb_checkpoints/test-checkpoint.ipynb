# %%
from pipeline import run_epidemiology
import os

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

run_epidemiology()                                          # all conditions in disease_landscape
run_epidemiology("Sickle Cell Disease")                     # specific list
# Out:
# disease_landscape table not found — run run_landscape(conditions) first, or pass conditions directly: run_epidemiology(['Sickle Cell Disease'])
# INFO epidemiology table ready
# INFO Refreshing epidemiology for 1 conditions
# INFO ── Sickle Cell Disease
# INFO Loading GBD CSV from gbd_data.csv …
# INFO Filtered to standard population group (2840 rows)
# INFO GBD CSV loaded: 2840 rows after filtering
# INFO Population groups in filtered data: ['All Population']
# INFO GBD  Sickle Cell Disease                      prevalence   number       = 7825798 (2023)
# INFO GBD  Sickle Cell Disease                      prevalence   rate_per_100k = 97 (2023)
# INFO GBD  Sickle Cell Disease                      prevalence   number       = 58927 (2023)
# INFO GBD  Sickle Cell Disease                      prevalence   rate_per_100k = 18 (2023)
# INFO GBD  Sickle Cell Disease                      incidence    number       = 538125 (2023)
# INFO GBD  Sickle Cell Disease                      incidence    rate_per_100k = 7 (2023)
# INFO GBD  Sickle Cell Disease                      incidence    number       = 1209 (2023)
# INFO GBD  Sickle Cell Disease                      incidence    rate_per_100k = 0 (2023)
# INFO Refresh complete.
