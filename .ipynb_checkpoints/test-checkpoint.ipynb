# %%
import requests
r = requests.get('https://clinicaltrials.gov/api/v2/studies/NCT05838430')
data = r.json()
print(data['hasResults'])
print(data.get('resultsSection', 'No results yet'))
# Out:
# False
# No results yet
