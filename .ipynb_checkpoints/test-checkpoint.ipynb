# %%
from mappings import get_sec_universe

get_sec_universe()
# Out:
# SIC 2836: 489 companies
# SIC 2835: 151 companies
# SIC 2830: 0 companies
# SIC 8731: 181 companies
# SIC 3841: 587 companies
# SIC 3845: 260 companies
# SIC 3826: 108 companies
# SIC 3827: 43 companies
# Total unique CIKs: 1819
# SEC universe: 439 companies with valid tickers
# [{'ticker': 'AGEN', 'name': 'agenus'},
#  {'ticker': 'BDX', 'name': 'becton dickinson &'},
#  {'ticker': 'YBGJ', 'name': 'yubo international biotech'},
#  {'ticker': 'BZYR', 'name': 'burzynski research institute'},
#  {'ticker': 'GLUE', 'name': 'monte rosa therapeutics'},
#  {'ticker': 'PRME', 'name': 'prime medicine'},
#  {'ticker': 'CRDL', 'name': 'cardiol therapeutics'},
#  {'ticker': 'SOLV', 'name': 'solventum'},
#  {'ticker': 'CVM', 'name': 'cel sci'},
#  {'ticker': 'MMM', 'name': '3m'},
#  {'ticker': 'ENGNW', 'name': 'engene therapeutics'},
#  {'ticker': 'COAG', 'name': 'hemab therapeutics'},
#  {'ticker': 'SGHT', 'name': 'sight sciences'},
#  {'ticker': 'USAQ', 'name': 'qhslab'},
# ...
