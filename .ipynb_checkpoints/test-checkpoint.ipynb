# %%
from db import _get_last_snapshot, _has_changed, get_conn, safe
from scraper import fetch_trials
import os

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

last_status, last_enrollment, last_pcd = ('TERMINATED', 509, '2021-03-05')

new_enrollment = safe(509)
print("new_enrollment:", repr(new_enrollment))
print("str(last_enrollment):", repr(str(last_enrollment)))
print("equal:", new_enrollment == str(last_enrollment))
# Out:
# nct_id: NCT04393038 company: abivax
# last snapshot: ('TERMINATED', 509, '2021-03-05')
# new pcd: 2021-03-05
# last pcd: 2021-03-05
# has_changed: True
