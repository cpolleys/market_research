# %%
from mappings import get_sec_universe

get_sec_universe()
# Out:
# <?xml version="1.0" encoding="ISO-8859-1" ?>
#   <feed xmlns="http://www.w3.org/2005/Atom">
#     <author>
#       <email>webmaster@sec.gov</email>
#       <name>Webmaster</name>
#     </author>
#     <entry title="ARRAY(0x55b6f6c6fbc0)">
#       <content type="text/xml">
#         <company-info name="ARRAY(0x55b6f6dcc418)">
#           <addresses>
#             <address type="business">
#               <state>NY</state>
#             </address>
#             <address type="mailing" />
#           </addresses>
#           <cik>0001848948</cik>
#           <irs-number></irs-number>
#           <last-date>03 Life Sciences</last-date>
#           <sic>2836</sic>
#           <state>NY</state>
#         </company-info>
#       </content>
#       <id>urn:tag:www.sec.gov:cik=0001848948</id>
#       <link href="https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&amp;CIK=0001848948&amp;owner=exclude&amp;hidefilings=0" type="text/html" />
# ...
