# %%
import requests
r = requests.get('https://clinicaltrials.gov/api/v2/studies/NCT06119217')
data = r.json()
print(data['hasResults'])
print(data.get('resultsSection', 'No results yet'))
# Out:
# True
# ...
