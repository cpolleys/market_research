# %%
#from mappings import get_sec_universe

#get_sec_universe()

from pubmed import get_latest_publication
print(get_latest_publication('NCT04825743'))
# Out:
# {'pmid': '41755767', 'title': 'Hemostasis-Sparing Antiplatelet Therapy: Current Concepts and Emerging Targets in Arterial Thrombosis.', 'journal': 'Biomol Ther (Seoul)', 'pub_date': '2026-03-01'}
