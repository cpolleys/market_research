# %%
import sqlite3
import pandas as pd
from db import get_conn, _get_last_snapshot, _has_changed, safe
import os

from scraper import fetch_trials
trials = fetch_trials('amgen')
print(len(trials))
print(trials[0].keys())
print(trials[0].get('nct_id'))
# Out:
# 1581
# dict_keys(['nct_id', 'snapshot_date', 'title', 'phase', 'fda_regulated', 'status', 'sponsor', 'study_type', 'conditions', 'interventions', 'enrollment', 'start_date', 'primary_completion_date', 'primary_outcomes', 'secondary_outcomes', 'last_updated'])
# NCT00508820
