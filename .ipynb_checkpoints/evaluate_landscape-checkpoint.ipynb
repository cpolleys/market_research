# %%
import sqlite3
import pandas as pd
import os

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

df = pd.read_sql_query("""
    SELECT sponsor, phase, status, enrollment,
           primary_completion_date
    FROM disease_landscape
    WHERE condition_searched = 'ST Elevation Myocardial Infarction'
    AND phase IN ('PHASE2', 'PHASE3', 'PHASE4')
    AND primary_completion_date BETWEEN date('now') AND date('now', '+12 months')
    ORDER BY primary_completion_date
""", conn)

print(len(df))

print(df)
# Out:
# 272
#     company                                           sponsor   phase  \
# 0      None                               Kumamoto University  PHASE4
# 1      None                             The Medicines Company  PHASE3
# 2      None       Ottawa Heart Institute Research Corporation  PHASE3
# 3      None                        Odense University Hospital  PHASE4
# 4      None                   Sahlgrenska University Hospital  PHASE4
# ..      ...                                               ...     ...
# 267    None                              University of Aarhus  PHASE4
# 268    None  Instituto Nacional de Cardiologia Ignacio Chavez  PHASE4
# 269    None           Assistance Publique - Hôpitaux de Paris  PHASE3
# 270    None                          Montreal Heart Institute  PHASE3
# 271    None                                   Thomas Engstrom  PHASE3
#
#                  status primary_completion_date
# 0             COMPLETED                    None
# 1             COMPLETED                    None
# 2             COMPLETED                    None
# 3             COMPLETED                    None
# 4             COMPLETED                 2003-06
# ..                  ...                     ...
# 267          RECRUITING              2029-01-01
# 268          RECRUITING                 2029-06
# 269  NOT_YET_RECRUITING                 2029-06
# 270          RECRUITING              2030-01-01
# 271          RECRUITING              2031-04-20
#
# [272 rows x 5 columns]
