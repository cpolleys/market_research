# %%
import requests, json

nct_id = 'NCT03691714'
r = requests.get(f'https://clinicaltrials.gov/api/v2/studies/{nct_id}')
data = r.json()

print('Has results:', data.get('hasResults'))
print(json.dumps(data.get('resultsSection', {}), indent=2))
# Out:
# Has results: True
# {
#   "participantFlowModule": {
#     "groups": [
#       {
#         "id": "FG000",
#         "title": "Durvalumab and Cetuximab",
#         "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#       }
#     ],
#     "periods": [
#       {
#         "title": "Overall Study",
#         "milestones": [
#           {
#             "type": "STARTED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "35"
#               }
#             ]
#           },
#           {
#             "type": "COMPLETED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "35"
#               }
#             ]
#           },
#           {
#             "type": "NOT COMPLETED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "0"
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "baselineCharacteristicsModule": {
#     "populationDescription": "Between October 2018 and October 2021, 35 patients were enrolled, of whom 33 received at least 1 dose of durvalumab and were included in response analysis.",
#     "groups": [
#       {
#         "id": "BG000",
#         "title": "Durvalumab and Cetuximab",
#         "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#       }
#     ],
#     "denoms": [
#       {
#         "units": "Participants",
#         "counts": [
#           {
#             "groupId": "BG000",
#             "value": "35"
#           }
#         ]
#       }
#     ],
#     "measures": [
#       {
#         "title": "Age, Continuous",
#         "paramType": "MEDIAN",
#         "dispersionType": "INTER_QUARTILE_RANGE",
#         "unitOfMeasure": "years",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "64",
#                     "lowerLimit": "47",
#                     "upperLimit": "81"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Sex: Female, Male",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "Female",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "24"
#                   }
#                 ]
#               },
#               {
#                 "title": "Male",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "11"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Ethnicity (NIH/OMB)",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "Hispanic or Latino",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Not Hispanic or Latino",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Unknown or Not Reported",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "35"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Race (NIH/OMB)",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "American Indian or Alaska Native",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Asian",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Native Hawaiian or Other Pacific Islander",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Black or African American",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "2"
#                   }
#                 ]
#               },
#               {
#                 "title": "White",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "33"
#                   }
#                 ]
#               },
#               {
#                 "title": "More than one race",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Unknown or Not Reported",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Region of Enrollment",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "participants",
#         "classes": [
#           {
#             "title": "United States",
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "35"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "ECOG Status",
#         "description": "The ECOG (Eastern Cooperative Oncology Group) Performance Status is a 0-5 scale used by clinicians to assess a cancer patient's functional level and ability to tolerate therapies, such as chemotherapy. It assists in determining appropriate treatment, prognosis, and quality of life.",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "0 = Fully active; no restrictions",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "6"
#                   }
#                 ]
#               },
#               {
#                 "title": "1 = Restricted in strenuous activity but ambulatory",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "22"
#                   }
#                 ]
#               },
#               {
#                 "title": "2 = Ambulatory, capable of self-care, unable to work",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "7"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "outcomeMeasuresModule": {
#     "outcomeMeasures": [
#       {
#         "type": "PRIMARY",
#         "title": "Objective Response Rate",
#         "description": "Complete Response (CR), Disappearance of all target lesions; Partial Response (PR), \\>=30% decrease in the sum of the longest diameter of target lesions; Overall Response (OR) = CR + PR.",
#         "populationDescription": "Population included participants that had at least one dose of durvalumab.",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "RECIST 1.1 was assessed for each participant every 8 weeks from study initiation until the end of study treatment. The time from first RECIST 1.1 assessment to the final at the end of study was 8.5 months.",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Durvalumab and Cetuximab",
#             "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "33"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "13"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Treatment Related Adverse Events",
#         "description": "Percentage of adverse events that were treatment related and greater than or equal to Grade 3 using CTCAE v 5.0. Adverse events were recorded from time of signature of informed consent, throughout the treatment period and including the follow-up period (90 days after the last dose of durvalumab + cetuximab).",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "percentage of all adverse events",
#         "timeFrame": "From informed consent through study treatment and the 90-day safety follow-up period after the last dose of durvalumab and cetuximab, up to 24 months",
#         "typeUnitsAnalyzed": "Number of adverse events",
#         "denomUnitsSelected": "Number of adverse events",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Durvalumab and Cetuximab",
#             "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "35"
#               }
#             ]
#           },
#           {
#             "units": "Number of adverse events",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "873"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "9"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Disease Control Rate",
#         "description": "Combined complete response, partial response, and stable disease",
#         "populationDescription": "Subjects received at least one dose of Durvalumab.",
#         "reportingStatus": "POSTED",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "timeFrame": "6 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Durvalumab and Cetuximab",
#             "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "33"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "20"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Progression-free Survival",
#         "description": "Imaging review using RECIST 1.1 Progression is defined using Response Evaluation Criteria In Solid Tumors Criteria (RECIST v1.0), as a 20% increase in the sum of the longest diameter of target lesions, or a measurable increase in a non-target lesion, or the appearance of new lesions",
#         "reportingStatus": "POSTED",
#         "paramType": "MEDIAN",
#         "dispersionType": "95% Confidence Interval",
#         "unitOfMeasure": "months",
#         "timeFrame": "24 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Durvalumab and Cetuximab",
#             "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "35"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "5.8",
#                     "lowerLimit": "3.7",
#                     "upperLimit": "14.1"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Overall Survival",
#         "description": "Date of on treatment to date of death",
#         "reportingStatus": "POSTED",
#         "paramType": "MEDIAN",
#         "dispersionType": "95% Confidence Interval",
#         "unitOfMeasure": "months",
#         "timeFrame": "24 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Durvalumab and Cetuximab",
#             "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "35"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "9.6",
#                     "lowerLimit": "4.8",
#                     "upperLimit": "16.3"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "adverseEventsModule": {
#     "frequencyThreshold": "0",
#     "timeFrame": "Adverse events were recorded from time of signature of informed consent, throughout the treatment period and including the follow-up period (90 days after the last dose of durvalumab + cetuximab).The median length of collection was 4.2 months (0.46 months - 24.50 months).",
#     "description": "Our system does not differ from ct.gov.",
#     "eventGroups": [
#       {
#         "id": "EG000",
#         "title": "Durvalumab and Cetuximab",
#         "description": "Durvalumab 500mg as a 120-minute intravenous infusion every two weeks. Cetuximab 400mg/m2 IV loading dose followed by weekly Cetuximab 250mg/m2 IV Treatment with Durvalumab continues until progression and Cetuximab may continue as maintenance\n\nDurvalumab: Two hour infusion\n\nCetuximab: Two hour infusion for loading dose followed by weekly one hour infusion",
#         "deathsNumAffected": 1,
#         "deathsNumAtRisk": 35,
#         "seriousNumAffected": 24,
#         "seriousNumAtRisk": 35,
#         "otherNumAffected": 35,
#         "otherNumAtRisk": 35
#       }
#     ],
#     "seriousEvents": [
#       {
#         "term": "Leukocytosis",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Sinus tachycardia",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Diabetes mellitus type 1",
#         "organSystem": "Endocrine disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Diabetic ketoacidosis",
#         "organSystem": "Endocrine disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eye chemosis/inflammation",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Colonic hemorrhage",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Diarrhea",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hematemesis",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Oral cavity fistula",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Vomiting",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Death NOS",
#         "organSystem": "General disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Edema face",
#         "organSystem": "General disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Fever",
#         "organSystem": "General disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Device related infection",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Lung infection",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Sepsis",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Surgical site infection",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Fall",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Fracture",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Tracheal obstruction",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Tracheostomy site bleeding",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Anorexia",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Dehydration",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Failure to thrive",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Osteonecrosis of jaw",
#         "organSystem": "Musculoskeletal and connective tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Encephalopathy",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Spinal cord compression",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Confusion",
#         "organSystem": "Psychiatric disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Acute kidney injury",
#         "organSystem": "Renal and urinary disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Aspiration",
#         "organSystem": "Reproductive system and breast disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "HCAP/aspiration pneumonia with acute hypoxic respiratory failure",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hemoptysis",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Lung Infection/Pneumonia",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hypotension",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Thromboembolic event",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       }
#     ],
#     "otherEvents": [
#       {
#         "term": "Anemia",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 15,
#             "numAffected": 3,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Cervical adenopathy",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Leukocytosis",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Macrocytic Anemia",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Atrial fibrillation",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Atrial flutter",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Chest pain - cardiac",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Cyanosis",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Palpitations",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Pericardial effusion",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Sinus tachycardia",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Ear drainage",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Ear fullness",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Ear inflammation",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Ear pain",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 5,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hearing impaired",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Vertigo",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Vestibular disorder",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Diabetes mellitus type 1",
#         "organSystem": "Endocrine disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Diabetic ketoacidosis",
#         "organSystem": "Endocrine disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hypothyroidism",
#         "organSystem": "Endocrine disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Blurred vision",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 3,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Dry eye",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eye chemosis, orbital apex inflammation extending into Cavernous sinus",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eye discharge",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eye Etropian",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eye inflammation",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eyelid function disorder",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Fuzzy vision",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Itchy eyes",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Periorbital dermatitis",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Periorbital edema",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Scleral disorder",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Uveitis",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Vision decreased",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Abdominal distension",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Abdominal pain",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Bloating",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Chipped tooth",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Colitis",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Colonic hemorrhage",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Constipation",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 8,
#             "numAffected": 6,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Dental caries",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Diarrhea",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 18,
#             "numAffected": 11,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Drooling",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
# ...
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Thick secretions",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Tracheal mucositis",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Voice alteration",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Wheezing",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Alopecia",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Brittle nails",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Dry skin",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 23,
#             "numAffected": 13,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Erythema around PEG tube site",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Erythema-face",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eyelash crusty",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Eyelashes falling out",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Fingertips cracking/splitting/peeling",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 3,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Fissues",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Nail changes",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Nail loss",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Nail ridging",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Neck edema",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Necrotic lesion",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Palmar-plantar erythrodysesthesia syndrome",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Pressure sore",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Pruritus",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 16,
#             "numAffected": 9,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Purpura",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Rash acneiform",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 60,
#             "numAffected": 27,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Rash maculo-papular",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 9,
#             "numAffected": 5,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Skin breakdown",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Skin irritation around g-tube",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Skin ulceration",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 4,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Mouth irritation",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Toenail pain",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Skin and Other Subcutaneous Tissue Disorders (Unknown)",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Urticaria",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Esophagram",
#         "organSystem": "Surgical and medical procedures",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Feed tube replacement",
#         "organSystem": "Surgical and medical procedures",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "PEG place",
#         "organSystem": "Surgical and medical procedures",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Flushing",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hypertension",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Hypotension",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 4,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Lymphedema",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Pulmonary embolism",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 35
#           }
#         ]
#       },
#       {
#         "term": "Thromboembolic event",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE (Unspecified)",
#         "assessmentType": "SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 2,
#             "numAtRisk": 35
#           }
#         ]
#       }
#     ]
#   },
#   "moreInfoModule": {
#     "certainAgreement": {
#       "piSponsorEmployee": false,
#       "restrictiveAgreement": false
#     },
#     "pointOfContact": {
#       "title": "Trisha Wise-Draper M.D., Ph.D.",
#       "organization": "University of Cincinnati Cancer Center",
#       "email": "wiseth@ucmail.uc.edu",
#       "phone": "(513) 558-2826"
#     }
#   }
# }
