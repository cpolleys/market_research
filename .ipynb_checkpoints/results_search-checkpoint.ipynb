# %%
import requests, json

nct_id = 'NCT05326464'
r = requests.get(f'https://clinicaltrials.gov/api/v2/studies/{nct_id}')
data = r.json()

print('Has results:', data.get('hasResults'))
print(json.dumps(data.get('resultsSection', {}), indent=2))
# Out:
# Has results: True
# {
#   "participantFlowModule": {
#     "groups": [
#       {
#         "id": "FG000",
#         "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#         "description": "Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5"
#       },
#       {
#         "id": "FG001",
#         "title": "Recurrent Disease on Temozolomide",
#         "description": "Tofacitinib 10mg BID x Lomustine 90mg/m2 on day 1"
#       }
#     ],
#     "periods": [
#       {
#         "title": "Overall Study",
#         "milestones": [
#           {
#             "type": "STARTED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "9"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "9"
#               }
#             ]
#           },
#           {
#             "type": "COMPLETED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "9"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "9"
#               }
#             ]
#           },
#           {
#             "type": "NOT COMPLETED",
#             "achievements": [
#               {
#                 "groupId": "FG000",
#                 "numSubjects": "0"
#               },
#               {
#                 "groupId": "FG001",
#                 "numSubjects": "0"
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "baselineCharacteristicsModule": {
#     "groups": [
#       {
#         "id": "BG000",
#         "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#         "description": "Participants will take Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5.\n\nTofacitinib 10mg: 10 mg given orally twice daily until evidence of progression, intolerance of treatment, withdrawal of consent, or death.\n\nTemozolomide: Temozolomide 150mg/m2 - 200mg/m2 on days 1-5"
#       },
#       {
#         "id": "BG001",
#         "title": "Recurrent Disease on Temozolomide",
#         "description": "Tofacitinib 10mg BID x 42 days Lomustine 90mg/m2\n\nTofacitinib 10mg: 10 mg given orally twice daily until evidence of progression, intolerance of treatment, withdrawal of consent, or death.\n\nLomustine: Lomustine 90mg/m2 on day 1"
#       },
#       {
#         "id": "BG002",
#         "title": "Total",
#         "description": "Total of all reporting groups"
#       }
#     ],
#     "denoms": [
#       {
#         "units": "Participants",
#         "counts": [
#           {
#             "groupId": "BG000",
#             "value": "9"
#           },
#           {
#             "groupId": "BG001",
#             "value": "9"
#           },
#           {
#             "groupId": "BG002",
#             "value": "18"
#           }
#         ]
#       }
#     ],
#     "measures": [
#       {
#         "title": "Age, Categorical",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "<=18 years",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Between 18 and 65 years",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "4"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "6"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "10"
#                   }
#                 ]
#               },
#               {
#                 "title": ">=65 years",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "5"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "3"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "8"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Age, Continuous",
#         "paramType": "MEAN",
#         "dispersionType": "FULL_RANGE",
#         "unitOfMeasure": "years",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "60.56",
#                     "lowerLimit": "46",
#                     "upperLimit": "73"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "63.67",
#                     "lowerLimit": "44",
#                     "upperLimit": "75"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "62.11",
#                     "lowerLimit": "44",
#                     "upperLimit": "75"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Sex: Female, Male",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "Female",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "4"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "3"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "7"
#                   }
#                 ]
#               },
#               {
#                 "title": "Male",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "5"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "6"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "11"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Ethnicity (NIH/OMB)",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "Hispanic or Latino",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Not Hispanic or Latino",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "7"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "7"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "14"
#                   }
#                 ]
#               },
#               {
#                 "title": "Unknown or Not Reported",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "2"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "2"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "4"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Race (NIH/OMB)",
#         "paramType": "COUNT_OF_PARTICIPANTS",
#         "unitOfMeasure": "Participants",
#         "classes": [
#           {
#             "categories": [
#               {
#                 "title": "American Indian or Alaska Native",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Asian",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Native Hawaiian or Other Pacific Islander",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Black or African American",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "1"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "1"
#                   }
#                 ]
#               },
#               {
#                 "title": "White",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "6"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "7"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "13"
#                   }
#                 ]
#               },
#               {
#                 "title": "More than one race",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "0"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "0"
#                   }
#                 ]
#               },
#               {
#                 "title": "Unknown or Not Reported",
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "2"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "2"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "4"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "title": "Region of Enrollment",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "participants",
#         "classes": [
#           {
#             "title": "United States",
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "BG000",
#                     "value": "9"
#                   },
#                   {
#                     "groupId": "BG001",
#                     "value": "9"
#                   },
#                   {
#                     "groupId": "BG002",
#                     "value": "18"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "outcomeMeasuresModule": {
#     "outcomeMeasures": [
#       {
#         "type": "PRIMARY",
#         "title": "Progression-free Survival (PFS) of the Study Cohort as Defined by RANO Criteria.",
#         "description": "Median progression-free survival from initiation of Tofacitinib until disease progression as defined by the RANO criteria, unacceptable toxicity, withdrawal of consent, or discontinuation from the trial for any other reason.",
#         "reportingStatus": "POSTED",
#         "paramType": "MEDIAN",
#         "dispersionType": "95% Confidence Interval",
#         "unitOfMeasure": "months",
#         "timeFrame": "From treatment initiation until documented radiographic or clinical progression by RANO criteria or death, whichever came first, assessed up to 2 years.",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#             "description": "Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5"
#           },
#           {
#             "id": "OG001",
#             "title": "Recurrent Disease on Temozolomide",
#             "description": "Tofacitinib 10mg BID x Lomustine 90mg/m2 on day 1"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "9"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "9"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "4",
#                     "lowerLimit": "0",
#                     "upperLimit": "24"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "4",
#                     "lowerLimit": "0",
#                     "upperLimit": "24"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Overall Survival (OS) of the Study Cohort.",
#         "description": "Median OS of the study patients from time of study entry until death or lost to follow-up.",
#         "reportingStatus": "POSTED",
#         "paramType": "MEAN",
#         "dispersionType": "95% Confidence Interval",
#         "unitOfMeasure": "months",
#         "timeFrame": "From treatment initiation until documented radiographic or clinical progression by RANO criteria or death, whichever came first, assessed up to 2 years.",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#             "description": "Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5"
#           },
#           {
#             "id": "OG001",
#             "title": "Recurrent Disease on Temozolomide",
#             "description": "Tofacitinib 10mg BID x Lomustine 90mg/m2 on day 1"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "9"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "9"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "13.1",
#                     "lowerLimit": "0",
#                     "upperLimit": "24"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "13.1",
#                     "lowerLimit": "0",
#                     "upperLimit": "24"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Percentage of Treatment Related Adverse Events",
#         "description": "Assess safety and tolerability associated with Tofacitinib 5 mg orally twice daily when administered to GBM patients. NCI Common terminology criteria for adverse events (CTCAE v.5) will be used to assess the adverse events.",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "unitOfMeasure": "percentage of possibly related events",
#         "timeFrame": "Up to 2 years after completion of study treatment, an average of 34 months",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#             "description": "Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5"
#           },
#           {
#             "id": "OG001",
#             "title": "Recurrent Disease on Temozolomide",
#             "description": "Tofacitinib 10mg BID x Lomustine 90mg/m2 on day 1"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "9"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "9"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "100"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "100"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "SECONDARY",
#         "title": "Radiographic Response Rate by RANO Criteria (Number of Participants With Response)",
#         "description": "Tumor response will be assessed using contrast and non-contrast brain magnetic resonance imaging (MRI) with assessments based on the international criteria proposed by the Response Assessment in Neuro-Oncology (RANO) Working Group, until progression of disease. For patients who do not progress or die, PFS will be censored at the last adequate radiologic assessment.\n\nRANO criteria:\n\nComplete Response (CR): Complete disappearance of all enhancing measurable and non measurable disease sustained for at least 4 weeks; Partial Response (PR): \u226550% decrease compared to baseline in the sum of products of perpendicular diameters of all measurable enhancing lesions sustained for at least 4 weeks; Progressive Disease (PD): \u226525% increase in the sum of products of perpendicular diameters of enhancing lesions compared to the smallest tumor measurement obtained either at baseline (if no decrease) or best response, on stable or increasing doses of corticosteroids;",
#         "reportingStatus": "POSTED",
#         "paramType": "NUMBER",
#         "dispersionType": "95% Confidence Interval",
#         "unitOfMeasure": "participants",
#         "timeFrame": "From treatment initiation until documented radiographic response by RANO criteria or death, whichever came first, assessed up to 2 years.",
#         "groups": [
#           {
#             "id": "OG000",
#             "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#             "description": "Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5"
#           },
#           {
#             "id": "OG001",
#             "title": "Recurrent Disease on Temozolomide",
#             "description": "Tofacitinib 10mg BID x Lomustine 90mg/m2 on day 1"
#           }
#         ],
#         "denoms": [
#           {
#             "units": "Participants",
#             "counts": [
#               {
#                 "groupId": "OG000",
#                 "value": "9"
#               },
#               {
#                 "groupId": "OG001",
#                 "value": "9"
#               }
#             ]
#           }
#         ],
#         "classes": [
#           {
#             "categories": [
#               {
#                 "measurements": [
#                   {
#                     "groupId": "OG000",
#                     "value": "0",
#                     "lowerLimit": "0",
#                     "upperLimit": "0"
#                   },
#                   {
#                     "groupId": "OG001",
#                     "value": "0",
#                     "lowerLimit": "0",
#                     "upperLimit": "0"
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "adverseEventsModule": {
#     "frequencyThreshold": "0",
#     "timeFrame": "2 years, 10 months",
#     "eventGroups": [
#       {
#         "id": "EG000",
#         "title": "Newly Diagnosed or Recurrent Off Temozolomide",
#         "description": "Tofacitinib 10mg BID x 28 days with Temozolomide 150mg/m2 on days 1-5",
#         "deathsNumAffected": 9,
#         "deathsNumAtRisk": 9,
#         "seriousNumAffected": 5,
#         "seriousNumAtRisk": 9,
#         "otherNumAffected": 9,
#         "otherNumAtRisk": 9
#       },
#       {
#         "id": "EG001",
#         "title": "Recurrent Disease on Temozolomide",
#         "description": "Tofacitinib 10mg BID x Lomustine 90mg/m2 on day 1",
#         "deathsNumAffected": 9,
#         "deathsNumAtRisk": 9,
#         "seriousNumAffected": 2,
#         "seriousNumAtRisk": 9,
#         "otherNumAffected": 9,
#         "otherNumAtRisk": 9
#       }
#     ],
#     "seriousEvents": [
#       {
#         "term": "Depressed level of consciousness",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Edema",
#         "organSystem": "General disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Lymphocyte count decreased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Anemia",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Neutrophil count decreased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Hypertension",
#         "organSystem": "Hepatobiliary disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Seizure",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       }
#     ],
#     "otherEvents": [
#       {
#         "term": "Pain",
#         "organSystem": "General disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Sinusitis",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Abdominal Pain",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Allergic reaction",
#         "organSystem": "Immune system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Allergic rhinitis",
#         "organSystem": "Immune system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Muscle weakness lower limb",
#         "organSystem": "Musculoskeletal and connective tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Muscle Weakness left-sided",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Anemia",
#         "organSystem": "Blood and lymphatic system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 14,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Arthralgia",
#         "organSystem": "Musculoskeletal and connective tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Blood lactate dehydrogenase increased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Bullous dermatitis",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Cholesterol high",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Depressed level of consciousness",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dry eye",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dysarthria",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dysgeusia",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dyspepsia",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dysphasia",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Facial muscle weaknes",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Fall",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 8,
#             "numAffected": 4,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Gait disturbance",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Gastroesophageal reflux disease",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Generalized muscle weakness",
#         "organSystem": "Musculoskeletal and connective tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Headache",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 8,
#             "numAffected": 4,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Hyperglycemia",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 4,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Hypertriglyceridemia",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Hypokalemia",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Lymphocyte count decreased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 33,
#             "numAffected": 6,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Paresthesia",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Platelet count decreased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 13,
#             "numAffected": 6,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Seizure",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 9,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Shingles",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Skin Infection",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Somnolence",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Tinnitus",
#         "organSystem": "Ear and labyrinth disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Wheezing",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Wound complication",
#         "organSystem": "Injury, poisoning and procedural complications",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Alanine aminotransferase increased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Electrocardiogram T wave abnormal",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Neutrophil count decreased",
#         "organSystem": "Investigations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Pharyngitis",
#         "organSystem": "Infections and infestations",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Presyncope",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Edema cerebral",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 4,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Hypertension",
#         "organSystem": "Vascular disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Fatigue",
#         "organSystem": "General disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 5,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Insomnia",
#         "organSystem": "Psychiatric disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Weight gain",
#         "organSystem": "Metabolism and nutrition disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Cognitive disturbance",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Confusion",
#         "organSystem": "Psychiatric disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dizziness",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 5,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Memory impairment",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 4,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Agitation",
#         "organSystem": "Psychiatric disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Anxiety",
#         "organSystem": "Psychiatric disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Tremor",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Blurred Vision",
#         "organSystem": "Musculoskeletal and connective tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 6,
#             "numAffected": 4,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Back pain",
#         "organSystem": "Musculoskeletal and connective tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Eye pain",
#         "organSystem": "Eye disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Oral Pain",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Constipation",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 3,
#             "numAffected": 3,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Diarrhea",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Nausea",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 7,
#             "numAffected": 5,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Vomiting",
#         "organSystem": "Gastrointestinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Alopecia",
#         "organSystem": "Skin and subcutaneous tissue disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 2,
#             "numAffected": 2,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Dyspnea",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Hypoxia",
#         "organSystem": "Respiratory, thoracic and mediastinal disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Amnesia",
#         "organSystem": "Nervous system disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           }
#         ]
#       },
#       {
#         "term": "Atrial fibrillation",
#         "organSystem": "Cardiac disorders",
#         "sourceVocabulary": "CTCAE v5.",
#         "assessmentType": "NON_SYSTEMATIC_ASSESSMENT",
#         "stats": [
#           {
#             "groupId": "EG000",
#             "numEvents": 1,
#             "numAffected": 1,
#             "numAtRisk": 9
#           },
#           {
#             "groupId": "EG001",
#             "numEvents": 0,
#             "numAffected": 0,
#             "numAtRisk": 9
#           }
#         ]
#       }
#     ]
#   },
#   "moreInfoModule": {
#     "certainAgreement": {
#       "piSponsorEmployee": true
#     },
#     "pointOfContact": {
#       "title": "Dr. Michael Youssef",
#       "organization": "University of Texas Southwestern Medical Center",
#       "email": "michael.youssef@utsouthwestern.edu",
#       "phone": "214-648-5842"
#     }
#   }
# }
