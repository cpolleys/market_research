# %%
import sqlite3
import pandas as pd
import os
from mappings import resolve_company_sec, fetch_sec_tickers, get_biotech_universe, clean_name
from scraper import fetch_trials
import requests

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

conn = sqlite3.connect("biotech.db")

df = pd.read_sql_query("""
    SELECT company, nct_id, title, phase, status, conditions,
           primary_completion_date, enrollment
    FROM trials
    WHERE phase IN ('PHASE3', 'PHASE4')
    AND status = 'ACTIVE_NOT_RECRUITING'
    AND primary_completion_date BETWEEN date('now') AND date('now', '+6 months')
    ORDER BY primary_completion_date
""", conn)

print(len(df))
df.sort_values('primary_completion_date')[['company', 'phase', 'primary_completion_date', 'conditions', 'enrollment', 'nct_id']].head(20)
# Out:
# 280
#                    company   phase primary_completion_date  \
# 0                    amgen  PHASE4              2026-05-22
# 1                    amgen  PHASE4              2026-05-22
# 2                    amgen  PHASE4              2026-05-22
# 3                    amgen  PHASE4              2026-05-22
# 11     crispr therapeutics  PHASE3              2026-05-31
# ..                     ...     ...                     ...
# 275  definium therapeutics  PHASE3                 2026-11
# 277           scholar rock  PHASE3              2026-11-01
# 278           scholar rock  PHASE3              2026-11-01
# 276           scholar rock  PHASE3              2026-11-01
# 279           scholar rock  PHASE3              2026-11-01
#
#                                             conditions  enrollment  \
# 0    STEMI - ST Elevation Myocardial Infarction,NST...        2166
# 1    STEMI - ST Elevation Myocardial Infarction,NST...        2166
# 2    STEMI - ST Elevation Myocardial Infarction,NST...        2166
# 3    STEMI - ST Elevation Myocardial Infarction,NST...        2166
# 11   Beta-Thalassemia,Thalassemia,Genetic Diseases,...          16
# ..                                                 ...         ...
# 275                       Generalized Anxiety Disorder         250
# 277  Spinal Muscular Atrophy,Spinal Muscular Atroph...         238
# 278  Spinal Muscular Atrophy,Spinal Muscular Atroph...         238
# 276  Spinal Muscular Atrophy,Spinal Muscular Atroph...         238
# 279  Spinal Muscular Atrophy,Spinal Muscular Atroph...         238
#
#           nct_id
# 0    NCT04951856
# 1    NCT04951856
# 2    NCT04951856
# 3    NCT04951856
# 11   NCT05356195
# ..           ...
# 275  NCT06809595
# 277  NCT05626855
# 278  NCT05626855
# 276  NCT05626855
# 279  NCT05626855
#
# [280 rows x 6 columns]
