# %%
import sqlite3
import pandas as pd
import os

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

conn = sqlite3.connect("biotech.db")

df = pd.read_sql_query("SELECT * FROM trials", conn)

df.head()
# Out:
#         nct_id  company                                  sponsor  \
# 0  NCT05095844  Moderna                          Neuroganics LLC
# 1  NCT05074368  Moderna      National Taiwan University Hospital
# 2  NCT05033613  Moderna      National Taiwan University Hospital
# 3  NCT04805125  Moderna  University Hospital, Basel, Switzerland
# 4  NCT05033834  Moderna                        Assiut University
#
#                                                title   phase     status  \
# 0  National Vaccine Adverse Event Reporting Surve...    None    UNKNOWN
# 1  Efficacy and Safety of Heterologous and Homolo...      NA  COMPLETED
# 2  Home Blood Pressure Monitoring Before and Afte...    None    UNKNOWN
# 3  Immunocompromised Swiss Cohorts Based Trial Pl...  PHASE3  COMPLETED
# 4            Covid-19 Infection in After Vaccination    None    UNKNOWN
#
#        study_type                                         conditions  \
# 0   OBSERVATIONAL  COVID-19,Vaccine Adverse Reaction,Vaccine Reac...
# 1  INTERVENTIONAL                           Healthy Adult Volunteers
# 2   OBSERVATIONAL  Pain,Fatigue,Headache,Myalgia,Chills,Arthralgi...
# 3  INTERVENTIONAL                         Immunocompromised Patients
# 4   OBSERVATIONAL                                            Covid19
#
#                                        interventions  enrollment  start_date  \
# 0                                         vaccinated    100000.0  2022-03-15
# 1  ChAdOx1-nCov-19 (Astra-Zeneca),SARS-CoV-2 mess...       499.0  2021-07-06
# 2  heart rate、arrhythmia、blood pressure、central b...      1500.0  2021-09-10
# 3  Moderna COVID-19 Vaccine, mRNA-1273 (100 μg),P...       610.0  2021-04-19
# 4              covid-19 vaccines registered in Egypt       100.0  2021-11-01
#
#   primary_completion_date last_updated               snapshot_date
# 0              2024-04-01   2022-03-18  2026-04-25T00:57:40.806105
# 1              2022-04-27   2022-10-18  2026-04-25T00:57:40.806105
# 2              2022-12-29   2021-09-16  2026-04-25T00:57:40.806105
# 3              2023-09-23   2024-01-25  2026-04-25T00:57:40.806105
# 4              2022-11-01   2021-09-13  2026-04-25T00:57:40.806105
