# %%
import sqlite3
import pandas as pd
import os
from mappings import resolve_company_sec, fetch_sec_tickers, get_biotech_universe, clean_name
from scraper import fetch_trials
import requests

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

conn = sqlite3.connect("biotech.db")

df = pd.read_sql_query("""
    SELECT company, nct_id, title, phase, status, conditions,
           primary_completion_date, enrollment
    FROM trials
    WHERE phase IN ('PHASE3', 'PHASE4')
    AND status = 'ACTIVE_NOT_RECRUITING'
    AND primary_completion_date BETWEEN date('now') AND date('now', '+6 months')
    ORDER BY primary_completion_date
""", conn)

print(len(df))
df.sort_values('primary_completion_date')[['company', 'phase', 'primary_completion_date', 'conditions', 'enrollment', 'nct_id']]
# Out:
# 272
#                  company   phase primary_completion_date  \
# 0    united therapeutics  PHASE3              2026-05-13
# 1    united therapeutics  PHASE4              2026-05-13
# 2    united therapeutics  PHASE3              2026-05-15
# 3    united therapeutics  PHASE4              2026-05-18
# 4    united therapeutics  PHASE3              2026-05-21
# ..                   ...     ...                     ...
# 266  united therapeutics  PHASE3                 2026-11
# 267  united therapeutics  PHASE3                 2026-11
# 269     adc therapeutics  PHASE3                 2026-11
# 270         scholar rock  PHASE3              2026-11-01
# 271  united therapeutics  PHASE3              2026-11-05
#
#                                             conditions  enrollment
# 0           ST-elevation Myocardial Infarction (STEMI)        2463
# 1         Intracranial Hemorrhages,Atrial Fibrillation         948
# 2                                        Fabry Disease         104
# 3                                   Multiple Sclerosis          24
# 4                                     Chronic Migraine         759
# ..                                                 ...         ...
# 266                          Major Depressive Disorder         149
# 267                                 Multiple Sclerosis        1121
# 269                         Non-Small Cell Lung Cancer         406
# 270  Spinal Muscular Atrophy,Spinal Muscular Atroph...         238
# 271                                         Hemophilia         281
#
# [272 rows x 5 columns]
