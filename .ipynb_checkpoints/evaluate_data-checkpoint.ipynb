# %%
import sqlite3
import pandas as pd
import os
from mappings import resolve_company_sec, fetch_sec_tickers, get_biotech_universe, clean_name
from scraper import fetch_trials
import requests

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

conn = sqlite3.connect("biotech.db")

df = pd.read_sql_query("""
    SELECT company, nct_id, title, phase, status, conditions,
           primary_completion_date, enrollment
    FROM trials
    WHERE phase IN ('PHASE3', 'PHASE4')
    AND status = 'ACTIVE_NOT_RECRUITING'
    AND primary_completion_date BETWEEN date('now') AND date('now', '+6 months')
    ORDER BY primary_completion_date
""", conn)

print(len(df))
df.sort_values('primary_completion_date')[['company', 'phase', 'primary_completion_date', 'conditions', 'enrollment', 'nct_id']].head(20)
# Out:
# 70
#                       company   phase primary_completion_date  \
# 0                       amgen  PHASE4              2026-05-22
# 1         crispr therapeutics  PHASE3              2026-05-31
# 2         crispr therapeutics  PHASE3              2026-05-31
# 10            gilead sciences  PHASE3                 2026-06
# 9             gilead sciences  PHASE3                 2026-06
# 7                 cg oncology  PHASE3                 2026-06
# 8       ionis pharmaceuticals  PHASE3                 2026-06
# 5   arrowhead pharmaceuticals  PHASE3                 2026-06
# 4   arrowhead pharmaceuticals  PHASE3                 2026-06
# 3        revolution medicines  PHASE3                 2026-06
# 6                cytokinetics  PHASE3                 2026-06
# 11  regeneron pharmaceuticals  PHASE3              2026-06-08
# 12  regeneron pharmaceuticals  PHASE3              2026-06-08
# 13                      amgen  PHASE3              2026-06-22
# 18            zenas biopharma  PHASE3              2026-06-30
# 19        akebia therapeutics  PHASE3              2026-06-30
# 17   kalvista pharmaceuticals  PHASE3              2026-06-30
# 16   kalvista pharmaceuticals  PHASE3              2026-06-30
# 15                   celcuity  PHASE3              2026-06-30
# 14           ptc therapeutics  PHASE3              2026-06-30
#
#                                            conditions  enrollment       nct_id
# 0   STEMI - ST Elevation Myocardial Infarction,NST...        2166  NCT04951856
# 1   Sickle Cell Disease,Hydroxyurea Failure,Hydrox...          13  NCT05329649
# 2   Beta-Thalassemia,Thalassemia,Genetic Diseases,...          16  NCT05356195
# 10  Advanced Upper Gastrointestinal Tract Adenocar...        1040  NCT05568095
# 9                         Primary Biliary Cholangitis          90  NCT06060665
# 7   Non Muscle Invasive Bladder Cancer,Urologic Ca...         367  NCT06111235
# 8                       Amyotrophic Lateral Sclerosis          89  NCT04768972
# 5                         Severe Hypertriglyceridemia         311  NCT06347016
# 4                         Severe Hypertriglyceridemia         446  NCT06347003
# 3   Pancreatic Cancer,PDAC,PDAC - Pancreatic Ducta...         500  NCT06625320
# 6   Symptomatic Non-Obstructive Hypertrophic Cardi...         500  NCT06081894
# 11                           Lichen Simplex Chronicus         142  NCT06687967
# 12                           Lichen Simplex Chronicus         138  NCT06687980
# 13                                  Atopic Dermatitis        2621  NCT05882877
# 18                   Warm Autoimmune Hemolytic Anemia         134  NCT05786573
# 19                   Anemia of Chronic Kidney Disease        2200  NCT06520826
# 17                              Hereditary Angioedema         145  NCT05505916
# 16                              Hereditary Angioedema          11  NCT05511922
# 15                                      Breast Cancer         701  NCT05501886
# 14                                    Phenylketonuria         200  NCT05166161
