# %%
import sqlite3
import pandas as pd
import os
from mappings import resolve_company_sec, fetch_sec_tickers, get_biotech_universe, clean_name
from scraper import fetch_trials
import requests

save_dir = 'C:\\Users\\chris\Documents\\personal_projects'
os.chdir(save_dir)

conn = sqlite3.connect("biotech.db")

df = pd.read_sql_query("""
    SELECT company, nct_id, title, phase, status, conditions,
           primary_completion_date, enrollment
    FROM trials
    WHERE phase IN ('PHASE3', 'PHASE4')
    AND status = 'ACTIVE_NOT_RECRUITING'
    AND primary_completion_date BETWEEN date('now') AND date('now', '+6 months')
    ORDER BY primary_completion_date
""", conn)

#print(len(df))
#df.sort_values('primary_completion_date')[['company', 'phase', 'primary_completion_date', 'conditions', 'enrollment', 'nct_id']]
df.sort_values('primary_completion_date').head(10)
# Out:
#                company       nct_id  \
# 0  united therapeutics  NCT04825743
# 1  united therapeutics  NCT03950076
# 2  united therapeutics  NCT05280548
# 3  united therapeutics  NCT06444113
# 4  united therapeutics  NCT06047444
# 5  united therapeutics  NCT05976243
# 6  united therapeutics  NCT05817812
# 7                amgen  NCT04951856
# 8  united therapeutics  NCT04009499
# 9  united therapeutics  NCT06047457
#
#                                                title   phase  \
# 0  A Phase 3 Study of Zalunfiban in Subjects With...  PHASE3
# 1  EdoxabaN foR IntraCranial Hemorrhage Survivors...  PHASE4
# 2  A Study to Evaluate the Effect of Venglustat T...  PHASE3
# 3  Concentration of Ofatumumab in the Breast Milk...  PHASE4
# 4  A Study to Evaluate the Effectiveness and Safe...  PHASE3
# 5  A Study to Investigate Efficacy, Safety, and T...  PHASE3
# 6  A Study Evaluating Physical Activity and Joint...  PHASE3
# 7  Evolocumab or Normal Strategies to Reach LDL O...  PHASE4
# ...
