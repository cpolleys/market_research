# %%
import sqlite3
import pandas as pd
import os
from mappings import resolve_company_sec, fetch_sec_tickers, get_xbi_holdings, get_ibb_holdings

tickers = set(get_xbi_holdings() + get_ibb_holdings())

print(tickers)

#save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

#os.chdir(save_dir)

#conn = sqlite3.connect("biotech.db")

#df = pd.read_sql_query("SELECT * FROM trials", conn)

#df.head()
# Out:
#                                                   Name Ticker Identifier  \
# 0                          APELLIS PHARMACEUTICALS INC   APLS  03753U106
# 1                             REVOLUTION MEDICINES INC   RVMD  76155X100
# 2                             TRAVERE THERAPEUTICS INC   TVTX  89422G107
# 3                         ARROWHEAD PHARMACEUTICALS IN   ARWR  04280A100
# 4                                TWIST BIOSCIENCE CORP   TWST  90184D100
# ..                                                 ...    ...        ...
# 238                                                NaN    NaN        NaN
# 239                                                NaN    NaN        NaN
# 240                                                NaN    NaN        NaN
# 241                                                NaN    NaN        NaN
# 242  Before investing in a fund, consider its inves...    NaN        NaN
#
#        SEDOL    Weight Sector  Shares Held Local Currency
# 0    BYTQ6X1  1.865192      -    3789021.0            USD
# 1    BL71K91  1.647531      -     950970.0            USD
# 2    BLFGJD5  1.620524      -    3200549.0            USD
# 3    BYQBFJ8  1.439825      -    1630039.0            USD
# 4    BGKG6G7  1.419981      -    2020949.0            USD
# ..       ...       ...    ...          ...            ...
# 238      NaN       NaN    NaN          NaN            NaN
# 239      NaN       NaN    NaN          NaN            NaN
# 240      NaN       NaN    NaN          NaN            NaN
# 241      NaN       NaN    NaN          NaN            NaN
# 242      NaN       NaN    NaN          NaN            NaN
#
# [243 rows x 8 columns]
# {'CRBU', 'GLUE', 'ILMN', 'MBX', 'CTMX', 'ERAS', 'EBS', 'DFTX', 'PTCT', 'AUPH', '2200963D', 'ARGX', 'TECX', 'KYMR', 'SYRE', 'UTHR', 'RVMD', 'MGTX', 'RCUS', 'KYTX', 'TYRA', 'ALLO', 'CCCC', 'SGAFT', 'RGEN', 'BDTX', 'TRAX', 'TXG', 'AUTL', 'GHRS', 'NAMS', 'CPRX', 'KRYS', 'BCRX', 'SLS', 'PVLA', 'ABSI', 'ALT', 'MEDP', 'CSTL', 'PHAT', 'NTLA', 'HUMA', 'ZVRA', 'CABA', 'RIGL', 'BNTX', 'ADPT', 'GILD', 'IMNM', 'KALV', 'OPK', 'IXCM6', 'SANA', 'CNTA', 'SLDB', 'CRVS', 'AMGN', 'DSGN', 'IMCR', 'ACIU', 'VRTX', 'ARQT', 'CADL', 'XNCR', 'FLGT', 'TWST', 'AVBP', 'CATX', 'MENS', 'LRMR', 'REGN', 'KURA', 'GMAB', 'ASND', 'IMVT', 'CRL', 'RTYM6', 'PTGX', 'ALMS', 'ONC', 'JANX', 'GOSS', 'VRDN', 'VIR', 'CRSP', 'BIIB', 'RGNX', 'ZLAB', 'IONS', 'RXRX', 'AVIR', 'HALO', 'KROS', 'BBIO', 'ABBV', 'DNLI', 'FDMT', 'NVCR', 'SLN', 'ARDX', 'BHVN', 'MDXG', 'VYGR', 'ORIC', 'BIOA', 'RAPP', 'ARCT', 'XENE', 'AARD', 'PRAX', 'KOD', 'PRME', 'CRGX', 'ARWR', 'COGT', 'STOK', 'CDXS', 'GRAL', 'ROIV', 'PRTA', 'CAPR', 'MRVI', 'ALVO', 'TRDA', 'IMMP', 'MYGN', 'NUVL', 'VERA', 'CLDX', 'MDGL', 'APLS', 'NUVB', 'BCAX', 'UPB', 'ACRS', 'LYEL', 'AGIO', 'CDNA', 'FULC', 'DNTH', 'SRRK', 'LAB', 'MLYS', 'FHTX', 'PYXS', 'NBP', 'TNYA', 'TEM', 'MAZE', 'TSHA', 'NVAX', 'XTSLA', 'ANNX', 'ZYME', 'CTKB', 'BCYC', 'CGON', 'ADRO', 'PURR', 'RCKT', 'NGNE', 'URGN', 'IMRX', 'VCYT', 'IDYA', 'ARVN', 'CRNX', 'NRIX', 'OLMA', 'BMRN', 'SRPT', 'LXEO', 'FTRE', 'TRVI', 'SGMT', 'QSI', 'SION', 'IRON', 'ELVN', 'USD', 'APGE', 'PCVX', 'OABI', '-', 'THRD', 'ABVX', 'LEGN', 'PEPG', 'EXEL', 'AKE', 'ALNY', 'MESO', 'ALKS', 'GPCR', 'MIRM', 'AURA', 'GRFS', 'TGTX', 'NTRA', 'RARE', 'SMMT', 'TNGX', 'NMRA', 'WVE', 'PSNL', 'ADMA', 'GERN', 'INBX', 'PHVS', 'SNDX', '2200964D', 'GLPG', 'VKTX', 'ABUS', 'QTRX', 'EDIT', 'AMLX', 'CYTK', 'ORKA', 'AXSM', 'ANAB', 'LCTX', 'REPL', 'IBRX', 'VOR', 'ADCT', 'TVTX', '\xa0', 'SLNO', 'SEPN', 'CMPX', 'ATAI', 'IRWD', 'AKBA', 'STVN', 'VCEL', 'LENZ', 'DYN', 'RLAY', 'ZBIO', 'TBPH', 'BRKR', 'NBIX', 'VNDA', 'INCY', "The content contained herein is owned or licensed by BlackRock and/or its third-party information providers and is protected by applicable copyrights, trademarks, service marks, and/or other intellectual property rights. Such content is solely for your personal, non-commercial use. Accordingly, you may not copy, distribute, modify, post, frame or deep link this content. You may download material displayed on this Website for your personal use provided you also retain all copyright and other proprietary notices contained on the materials. Modification or use of the materials for any other purpose violates BlackRock's intellectual property rights.\nHoldings subject to change. See www.iShares.com for the most recent funds holdings.\nThe values for “price” shown herein generally represent a price provided by a third-party pricing vendor for the portfolio holding and do not reflect the impact of systematic fair valuation (“the vendor price”). The vendor price is not necessarily the price at which the Fund values the portfolio holding for the purposes of determining its net asset value (the “valuation price”). Additionally, where applicable, foreign currency exchange rates with respect to the portfolio holdings denominated in non-U.S. currencies for the valuation price will be generally determined as of the close of business on the New York Stock Exchange, whereas for the vendor price will be generally determined as of 4 p.m. London. The values shown herein for “market value,” “weight,” and “notional value” (the “calculated values”) are based off of the vendor price and may have been different if the valuation price were to have been used to calculate such values. The vendor price is as of the most recent practicable date and may not necessarily be as of the date shown above.\nPlease see the “Determination of Net Asset Value” section of each Fund’s prospectus for additional information on the Fund’s valuation policies and procedures.\nCAREFULLY CONSIDER THE FUNDS' INVESTMENT OBJECTIVES, RISK FACTORS, AND CHARGES  ...
