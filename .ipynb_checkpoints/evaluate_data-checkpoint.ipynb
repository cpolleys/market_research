# %%
import sqlite3
import pandas as pd
import os
from mappings import resolve_company_sec, fetch_sec_tickers, get_xbi_holdings, get_ibb_holdings

tickers = set(get_xbi_holdings() + get_ibb_holdings())

print(tickers)

#save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

#os.chdir(save_dir)

#conn = sqlite3.connect("biotech.db")

#df = pd.read_sql_query("SELECT * FROM trials", conn)

#df.head()
# Out:
# 3                            Name    Ticker Identifier    SEDOL    Weight  \
# 0     APELLIS PHARMACEUTICALS INC      APLS  03753U106  BYTQ6X1  1.865192
# 1        REVOLUTION MEDICINES INC      RVMD  76155X100  BL71K91  1.647531
# 2        TRAVERE THERAPEUTICS INC      TVTX  89422G107  BLFGJD5  1.620524
# 3    ARROWHEAD PHARMACEUTICALS IN      ARWR  04280A100  BYQBFJ8  1.439825
# 4           TWIST BIOSCIENCE CORP      TWST  90184D100  BGKG6G7  1.419981
# ..                            ...       ...        ...      ...       ...
# 150        CONTRA VERVE THERAPEUT         -  925CVR011        -  0.006818
# 151        CONTRA BLUEPRINT MEDIC         -  096CVR048        -  0.004183
# 152                     US DOLLAR         -  999USDZ92        -  0.000166
# 153     OMNIAB INC   12.5 EARNOUT  2200963D  68218J202  BP0VHM8         0
# 154    OMNIAB INC   15.00 EARNOUT  2200964D  68218J301  BP0VHL7         0
#
# 3   Sector Shares Held Local Currency
# 0        -     3789021            USD
# 1        -      950970            USD
# 2        -     3200549            USD
# 3        -     1630039            USD
# 4        -     2020949            USD
# ..     ...         ...            ...
# 150      -      900273            USD
# 151      -      756469            USD
# 152      -    13807.63            USD
# 153      -      161959            USD
# 154      -      161959            USD
#
# [155 rows x 8 columns]
#     Ticker                              Name                   Sector  \
# 0     AMGN                         AMGEN INC              Health Care
# 1     GILD               GILEAD SCIENCES INC              Health Care
# 2     VRTX        VERTEX PHARMACEUTICALS INC              Health Care
# 3     REGN     REGENERON PHARMACEUTICALS INC              Health Care
# 4     ALNY       ALNYLAM PHARMACEUTICALS INC              Health Care
# ..     ...                               ...                      ...
# 252      -    OMNIAB INC $12.50 VESTING Prvt              Health Care
# 253      -    OMNIAB INC $15.00 VESTING Prvt              Health Care
# 254  RTYM6     RUSSELL 2000 EMINI CME JUN 26  Cash and/or Derivatives
# 255  IXCM6  E-MINI HEALTH CARE SECTOR JUN 26  Cash and/or Derivatives
# 256    USD                          USD CASH  Cash and/or Derivatives
#
#     Asset Class    Market Value  Weight (%)  Notional Value        Quantity  \
# 0        Equity  596,846,360.00        7.46  596,846,360.00    1,723,744.00
# 1        Equity  587,738,513.60        7.35  587,738,513.60    4,492,040.00
# 2        Equity  575,560,766.22        7.20  575,560,766.22    1,346,719.00
# 3        Equity  533,042,635.16        6.67  533,042,635.16      753,886.00
# 4        Equity  301,431,189.89        3.77  301,431,189.89      973,961.00
# ..          ...             ...         ...             ...             ...
# 252      Equity            0.47        0.00            0.47       46,839.00
# 253      Equity            0.47        0.00            0.47       46,839.00
# 254     Futures            0.00        0.00    4,071,310.00           29.00
# 255     Futures            0.00        0.00    5,919,200.00           40.00
# 256        Cash  -33,389,456.57       -0.42  -33,389,456.57  -33,389,457.00
#
#         Price       Location                     Exchange Currency  FX Rate  \
# 0      346.25  United States                       NASDAQ      USD      1.0
# 1      130.84  United States                       NASDAQ      USD      1.0
# 2      427.38  United States                       NASDAQ      USD      1.0
# 3      707.06  United States                       NASDAQ      USD      1.0
# 4      309.49  United States                       NASDAQ      USD      1.0
# ..        ...            ...                          ...      ...      ...
# 252      0.00  United States    NO MARKET (E.G. UNLISTED)      USD      1.0
# 253      0.00  United States    NO MARKET (E.G. UNLISTED)      USD      1.0
# 254  2,807.80              -  Chicago Mercantile Exchange      USD      1.0
# 255  1,479.80              -  Chicago Mercantile Exchange      USD      1.0
# 256    100.00  United States                            -      USD      1.0
#
#     Market Currency Accrual Date
# 0               USD            -
# 1               USD            -
# 2               USD            -
# 3               USD            -
# 4               USD            -
# ..              ...          ...
# 252             USD            -
# 253             USD            -
# 254             USD            -
# 255             USD            -
# 256             USD            -
#
# [257 rows x 15 columns]
# {'SMMT', 'PRAX', 'TGTX', 'ALNY', 'DYN', 'MESO', 'MBX', 'SGAFT', 'EDIT', 'VERA', 'ANAB', 'VOR', 'CCCC', 'BMRN', 'RIGL', 'STOK', 'GILD', 'IMCR', 'ASND', 'OPK', 'BCRX', 'MGTX', 'LXEO', 'PHVS', 'DNA', 'NRIX', 'BRKR', 'AMLX', 'CMPS', 'TNYA', 'VCYT', 'TEM', 'AUPH', 'ENTA', 'NAMS', 'TRVI', 'BIIB', 'CTMX', 'PRTA', 'BBIO', 'NGNE', 'VCEL', 'MDGL', 'ADMA', 'INSM', 'MDXG', 'TXG', 'URGN', 'GRAL', 'AARD', 'GOSS', 'ROIV', '-', 'QTRX', 'CELC', 'JANX', 'MRVI', 'REGN', 'ELVN', 'EBS', 'SANA', 'SRPT', 'FULC', 'SGMT', 'ALT', 'NUVB', 'PYXS', 'VRDN', 'CRL', '2200964D', 'PTGX', 'QURE', 'UPB', 'CRSP', 'KALV', 'LYEL', 'RAPP', 'PTCT', 'BHVN', 'TKNO', 'ACAD', 'COGT', 'MAZE', 'MIRM', 'OABI', 'APGE', 'USD', 'IDYA', 'CPRX', 'ARVN', 'ZBIO', 'ACRS', 'LRMR', 'ALVO', 'ADCT', 'DFTX', 'CDXS', 'BBOT', 'CNTA', 'PGEN', 'ONC', 'CABA', 'DNLI', 'MNKD', 'TYRA', 'CDNA', 'KRYS', 'PVLA', 'CAPR', 'ZYME', 'WVE', 'EXEL', 'RVMD', 'ARQT', 'ZVRA', 'DMRA', 'BDTX', 'IMMP', 'RTYM6', 'ANNX', 'TVTX', 'XNCR', 'PEPG', 'ARCT', 'AVIR', 'APLS', 'INCY', 'NMRA', 'ALLO', 'SPRY', 'SLDB', 'IVVD', 'BCYC', 'CTKB', 'MLYS', 'TERN', 'NBP', 'CAI', 'RYTM', 'ORIC', 'PURR', 'VYGR', 'HUMA', 'CTNM', 'ADRO', 'REPL', 'CRGX', 'FHTX', 'GLPG', 'STVN', 'BNTX', 'ARDX', 'AKE', 'VRTX', 'PSNL', 'SLNO', 'ABBV', 'ARWR', 'SNDX', 'FTRE', 'AXSM', 'RXRX', 'CMPX', 'GPCR', 'SYRE', 'ABSI', 'IRWD', 'EWTX', 'ILMN', 'IBRX', 'CGEM', 'IMVT', 'NBIX', 'QSI', 'ERAS', 'VSTM', 'PACB', 'MRNA', 'TRAX', 'TECH', 'RARE', 'CSTL', 'RGNX', 'CATX', 'NUVL', 'LAB', 'OCGN', 'INBX', 'SRRK', 'ADPT', 'ALMS', 'AGIO', 'BIOA', 'IMRX', 'CRNX', 'VKTX', 'AVBP', 'SVRA', 'AKBA', 'ACIU', '2200963D', 'GHRS', 'SION', 'PCVX', 'CLLS', 'UTHR', 'AURA', 'MEDP', 'MENS', 'IOVA', 'ALKS', 'TARS', 'ABUS', 'OLMA', 'TSHA', 'AVXL', 'XENE', 'TRDA', 'KYTX', 'CGON', 'RCUS', 'THRD', 'SEPN', 'CRBU', 'CYTK', 'BEAM', 'TECX', 'GMAB', 'DSGN', 'NTLA', 'ABVX', 'ZLAB', 'ARGX', 'GLUE', 'KOD', 'CADL', 'SLN', 'TBPH', 'ABCL', 'FLGT', 'IXCM6', 'KURA', 'ATAI', 'VNDA', 'GERN', 'HALO', 'CLDX', 'TWST', 'LCTX', 'PHAT', 'TNGX', 'VIR', 'RLAY', 'BCAX', 'GRFS', 'KROS', 'IONS', 'LEGN', 'LENZ', 'ANRO', 'IMNM', 'MYGN', 'AUTL', 'SLS', 'AMGN', 'IRON', 'RCKT', 'NTRA', 'DNTH', 'PRME', 'KYMR', 'ORKA', 'FDMT', 'RGEN', 'CRVS', 'NVCR', 'XTSLA', 'NVAX'}
