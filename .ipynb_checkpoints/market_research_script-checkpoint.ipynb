# %%
from pipeline import run, run_landscape
import os

main_dir = 'C:\\Users\\chris\\Documents\\personal_projects\\market_research'
save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

#conditions = [
#        "ST Elevation Myocardial Infarction"
#    ]


run()
#run_landscape(conditions)
# Out:
# SIC 2836: 62 companies
# SIC 2835: 17 companies
# SIC 2830: 0 companies
# SIC 8731: 15 companies
# SIC 3841: 38 companies
# SIC 3845: 20 companies
# SIC 3826: 36 companies
# SIC 3827: 10 companies
# Total unique CIKs: 198
# SEC universe: 59 companies with valid tickers
# 4d molecular therapeutics: fetched 10 trials
# [1/198] 4d molecular therapeutics: 10 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [2/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [3/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [4/198] 03 life sciences: 0 new snapshots, 0 unchanged
# adma biologics: fetched 7 trials
# [5/198] adma biologics: 7 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [6/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [7/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [8/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [9/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [10/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [11/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [12/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [13/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [14/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [15/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [16/198] 03 life sciences: 0 new snapshots, 0 unchanged
# biocryst pharmaceuticals: fetched 56 trials
# [17/198] biocryst pharmaceuticals: 50 new snapshots, 6 unchanged
# 03 life sciences: fetched 0 trials
# [18/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [19/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [20/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [21/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [22/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [23/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [24/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [25/198] 03 life sciences: 0 new snapshots, 0 unchanged
# 03 life sciences: fetched 0 trials
# [26/198] 03 life sciences: 0 new snapshots, 0 unchanged
# celldex therapeutics: fetched 73 trials
# [27/198] celldex therapeutics: 70 new snapshots, 3 unchanged
# 03 life sciences: fetched 0 trials
# [28/198] 03 life sciences: 0 new snapshots, 0 unchanged
# absci: fetched 1 trials
# [29/198] absci: 1 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [30/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [31/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [32/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [33/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [34/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [35/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [36/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [37/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [38/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [39/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [40/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [41/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [42/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [43/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [44/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [45/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [46/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [47/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [48/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [49/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [50/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [51/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [52/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [53/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [54/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [55/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [56/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [57/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [58/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# 08 industrial applications and services: fetched 0 trials
# [59/198] 08 industrial applications and services: 0 new snapshots, 0 unchanged
# revolution medicines: fetched 20 trials
# [60/198] revolution medicines: 19 new snapshots, 1 unchanged
# travere therapeutics: fetched 19 trials
# [61/198] travere therapeutics: 19 new snapshots, 0 unchanged
# tg therapeutics: fetched 49 trials
# [62/198] tg therapeutics: 49 new snapshots, 0 unchanged
# alkermes: fetched 114 trials
# [63/198] alkermes: 113 new snapshots, 1 unchanged
# arrowhead pharmaceuticals: fetched 52 trials
# [64/198] arrowhead pharmaceuticals: 51 new snapshots, 1 unchanged
# madrigal pharmaceuticals: fetched 18 trials
# [65/198] madrigal pharmaceuticals: 18 new snapshots, 0 unchanged
# krystal biotech: fetched 17 trials
# [66/198] krystal biotech: 17 new snapshots, 0 unchanged
# cytokinetics: fetched 45 trials
# [67/198] cytokinetics: 45 new snapshots, 0 unchanged
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chris\AppData\Local\Temp/ipykernel_23656/3595948952.py", line 14, in <module>
#     run()
#   File "C:\Users\chris\Documents\personal_projects\market_research\pipeline.py", line 22, in run
#     trials = fetch_trials(company)
#   File "C:\Users\chris\Documents\personal_projects\market_research\scraper.py", line 17, in fetch_trials
#     response = requests.get(base_url, params=params)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py", line 644, in send
#     resp = conn.urlopen(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 358, in connect
#     conn = self._new_conn()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\connection.py", line 86, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\ntpath.py", line 664, in realpath
#     if _getfinalpathname(spath) == path:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chris\AppData\Local\Temp/ipykernel_23656/3595948952.py", line 14, in <module>
#     run()
#   File "C:\Users\chris\Documents\personal_projects\market_research\pipeline.py", line 22, in run
#     trials = fetch_trials(company)
#   File "C:\Users\chris\Documents\personal_projects\market_research\scraper.py", line 17, in fetch_trials
#     response = requests.get(base_url, params=params)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py", line 644, in send
#     resp = conn.urlopen(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 358, in connect
#     conn = self._new_conn()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\connection.py", line 86, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chris\AppData\Local\Temp/ipykernel_23656/3595948952.py", line 14, in <module>
#     run()
#   File "C:\Users\chris\Documents\personal_projects\market_research\pipeline.py", line 22, in run
#     trials = fetch_trials(company)
#   File "C:\Users\chris\Documents\personal_projects\market_research\scraper.py", line 17, in fetch_trials
#     response = requests.get(base_url, params=params)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py", line 644, in send
#     resp = conn.urlopen(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 358, in connect
#     conn = self._new_conn()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\connection.py", line 86, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3172, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
