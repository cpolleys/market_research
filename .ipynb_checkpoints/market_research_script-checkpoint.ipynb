# %%
from pipeline import run, run_landscape
import os

main_dir = 'C:\\Users\\chris\\Documents\\personal_projects\\market_research'
save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

#conditions = [
#        "ST Elevation Myocardial Infarction"
#    ]


run()
#run_landscape(conditions)
# Out:
# SIC 2836: 489 companies
# SIC 2835: 151 companies
# SIC 2834: 1891 companies
# SIC 8731: 181 companies
# SIC 3841: 587 companies
# SIC 3845: 260 companies
# SIC 3826: 108 companies
# SIC 3827: 43 companies
# Total unique CIKs: 3710
# SEC universe: 907 companies with valid tickers
# [1/914] adma biologics: 7 new snapshots, 0 unchanged
# [2/914] eledon pharmaceuticals: 9 new snapshots, 0 unchanged
# [3/914] inflarx: 16 new snapshots, 0 unchanged
# [4/914] cytomed therapeutics: 3 new snapshots, 0 unchanged
# [5/914] weed: 2 new snapshots, 0 unchanged
# [6/914] cvrx: 23 new snapshots, 0 unchanged
# [7/914] exelixis: 147 new snapshots, 3 unchanged
# [8/914] intelligent bio solutions: 2 new snapshots, 0 unchanged
# [9/914] collegium pharmaceutical: 3 new snapshots, 0 unchanged
# [10/914] aardvark therapeutics: 6 new snapshots, 0 unchanged
# [11/914] biomea fusion: 9 new snapshots, 0 unchanged
# [12/914] resmed: 165 new snapshots, 0 unchanged
# [13/914] lineage cell therapeutics: 5 new snapshots, 0 unchanged
# [14/914] beroni: 0 new snapshots, 0 unchanged
# [15/914] sellas life sciences: 8 new snapshots, 1 unchanged
# [16/914] coya therapeutics: 1 new snapshots, 0 unchanged
# [17/914] ars pharmaceuticals: 5 new snapshots, 0 unchanged
# [18/914] baxter: 353 new snapshots, 6 unchanged
# [19/914] protara therapeutics: 7 new snapshots, 0 unchanged
# [20/914] recursion pharmaceuticals a: 3 new snapshots, 0 unchanged
# [21/914] therapeuticsmd: 7 new snapshots, 0 unchanged
# [22/914] scisparc: 0 new snapshots, 0 unchanged
# [23/914] green planet bio engineering: 0 new snapshots, 0 unchanged
# [24/914] sutro biopharma: 8 new snapshots, 0 unchanged
# [25/914] telix pharmaceuticals: 31 new snapshots, 2 unchanged
# [26/914] nu-med plus: 0 new snapshots, 0 unchanged
# [27/914] moderna: 138 new snapshots, 0 unchanged
# [28/914] ocean biomedical: 3 new snapshots, 0 unchanged
# [29/914] aim immunotech: 15 new snapshots, 1 unchanged
# [30/914] acumen pharmaceuticals: 3 new snapshots, 0 unchanged
# [31/914] opko health: 60 new snapshots, 0 unchanged
# [32/914] oramed pharmaceuticals: 0 new snapshots, 0 unchanged
# [33/914] zymeworks: 7 new snapshots, 0 unchanged
# [34/914] camtek: 0 new snapshots, 0 unchanged
# [35/914] regenerex pharma: 0 new snapshots, 0 unchanged
# [36/914] adastra: 0 new snapshots, 0 unchanged
# [37/914] quantum cyber: 0 new snapshots, 0 unchanged
# [38/914] optimi health: 1 new snapshots, 0 unchanged
# [39/914] cellectar biosciences: 16 new snapshots, 0 unchanged
# [40/914] anika therapeutics: 19 new snapshots, 0 unchanged
# [41/914] microbot medical: 1 new snapshots, 0 unchanged
# [42/914] quince therapeutics: 10 new snapshots, 0 unchanged
# [43/914] can-fite biopharma: 22 new snapshots, 0 unchanged
# [44/914] seres therapeutics: 8 new snapshots, 1 unchanged
# [45/914] odyssey therapeutics: 2 new snapshots, 0 unchanged
# [46/914] replimune: 16 new snapshots, 1 unchanged
# [47/914] lixte biotechnology: 2 new snapshots, 0 unchanged
# [48/914] ocular therapeutix: 58 new snapshots, 0 unchanged
# [49/914] qiagen: 38 new snapshots, 0 unchanged
# [50/914] casi pharmaceuticals: 23 new snapshots, 1 unchanged
# [51/914] ctt pharmaceutical: 0 new snapshots, 0 unchanged
# [52/914] spero therapeutics: 24 new snapshots, 0 unchanged
# [53/914] agilent technologies: 1 new snapshots, 0 unchanged
# [54/914] skinvisible: 0 new snapshots, 0 unchanged
# [55/914] kalaris therapeutics: 0 new snapshots, 0 unchanged
# [56/914] olema pharmaceuticals: 6 new snapshots, 0 unchanged
# [57/914] acadia pharmaceuticals: 49 new snapshots, 1 unchanged
# [58/914] xbiotech: 8 new snapshots, 0 unchanged
# [59/914] davion healthcare: 0 new snapshots, 0 unchanged
# [60/914] ironwood pharmaceuticals: 42 new snapshots, 0 unchanged
# [61/914] curis: 19 new snapshots, 0 unchanged
# [62/914] accuray: 11 new snapshots, 0 unchanged
# [63/914] regen biopharma: 0 new snapshots, 0 unchanged
# [64/914] finch therapeutics: 0 new snapshots, 0 unchanged
# [65/914] bioage labs: 5 new snapshots, 0 unchanged
# [66/914] prf technologies: 0 new snapshots, 0 unchanged
# [67/914] bioharvest sciences: 0 new snapshots, 0 unchanged
# [68/914] q32 bio: 4 new snapshots, 0 unchanged
# [69/914] climb bio: 6 new snapshots, 0 unchanged
# [70/914] tela bio: 5 new snapshots, 0 unchanged
# [71/914] lipella pharmaceuticals: 4 new snapshots, 0 unchanged
# [72/914] precigen: 8 new snapshots, 0 unchanged
# [73/914] bridgebio oncology therapeutics: 3 new snapshots, 0 unchanged
# [74/914] compass pathways: 16 new snapshots, 0 unchanged
# [75/914] skinhealth systems: 0 new snapshots, 0 unchanged
# [76/914] c4 therapeutics: 5 new snapshots, 0 unchanged
# [77/914] one world products: 0 new snapshots, 0 unchanged
# [78/914] anebulo pharmaceuticals: 3 new snapshots, 0 unchanged
# [79/914] lexaria bioscience: 3 new snapshots, 0 unchanged
# [80/914] adicet bio: 0 new snapshots, 0 unchanged
# [81/914] kla: 0 new snapshots, 0 unchanged
# [82/914] soleno therapeutics: 7 new snapshots, 0 unchanged
# [83/914] werewolf therapeutics: 3 new snapshots, 0 unchanged
# [84/914] pfizer: 5930 new snapshots, 105 unchanged
# [85/914] corcept therapeutics: 79 new snapshots, 0 unchanged
# [86/914] elutia: 14 new snapshots, 0 unchanged
# [87/914] nika pharmaceuticals: 0 new snapshots, 0 unchanged
# [88/914] apyx medical: 10 new snapshots, 0 unchanged
# [89/914] eli lilly: 2787 new snapshots, 82 unchanged
# [90/914] hemab therapeutics: 0 new snapshots, 0 unchanged
# [91/914] okyo pharma: 2 new snapshots, 0 unchanged
# [92/914] lexicon pharmaceuticals: 68 new snapshots, 0 unchanged
# [93/914] silence therapeutics: 8 new snapshots, 0 unchanged
# [94/914] precision optics corporation: 0 new snapshots, 0 unchanged
# [95/914] greenwich lifesciences: 1 new snapshots, 0 unchanged
# [96/914] nextcure: 10 new snapshots, 0 unchanged
# [97/914] bluejay diagnostics: 7 new snapshots, 0 unchanged
# [98/914] cytosorbents: 26 new snapshots, 0 unchanged
# [99/914] mira pharmaceuticals: 0 new snapshots, 0 unchanged
# [100/914] enliven therapeutics: 4 new snapshots, 0 unchanged
# [101/914] relmada therapeutics: 10 new snapshots, 1 unchanged
# [102/914] foghorn therapeutics: 5 new snapshots, 0 unchanged
# [103/914] tuhura biosciences: 5 new snapshots, 1 unchanged
# [104/914] candel therapeutics: 13 new snapshots, 0 unchanged
# [105/914] lyell immunopharma: 7 new snapshots, 0 unchanged
# [106/914] mindmaze therapeutics: 0 new snapshots, 0 unchanged
# [107/914] inhibitor therapeutics: 0 new snapshots, 0 unchanged
# [108/914] sensei biotherapeutics: 4 new snapshots, 0 unchanged
# [109/914] avenue therapeutics: 3 new snapshots, 0 unchanged
# [110/914] krystal biotech: 17 new snapshots, 0 unchanged
# [111/914] agenus: 59 new snapshots, 2 unchanged
# [112/914] atara biotherapeutics: 9 new snapshots, 2 unchanged
# [113/914] legend biotech: 39 new snapshots, 0 unchanged
# [114/914] fulcrum therapeutics: 10 new snapshots, 0 unchanged
# [115/914] immunitybio: 85 new snapshots, 3 unchanged
# [116/914] aprea therapeutics: 15 new snapshots, 0 unchanged
# [117/914] maxcyte: 1 new snapshots, 0 unchanged
# [118/914] beone medicines: 102 new snapshots, 0 unchanged
# [119/914] procyon: 0 new snapshots, 0 unchanged
# [120/914] strata skin sciences: 1 new snapshots, 0 unchanged
# [121/914] elanco animal health: 0 new snapshots, 0 unchanged
# [122/914] xenon pharmaceuticals: 23 new snapshots, 0 unchanged
# [123/914] immunic: 8 new snapshots, 0 unchanged
# [124/914] plus therapeutics: 5 new snapshots, 0 unchanged
# [125/914] cannabis bioscience: 0 new snapshots, 0 unchanged
# [126/914] vireo growth: 0 new snapshots, 0 unchanged
# [127/914] insight molecular diagnostics: 3 new snapshots, 0 unchanged
# [128/914] inovio pharmaceuticals: 54 new snapshots, 0 unchanged
# [129/914] rani therapeutics: 5 new snapshots, 0 unchanged
# [130/914] gridai technologies: 0 new snapshots, 0 unchanged
# [131/914] abbott laboratories: 1 new snapshots, 1 unchanged
# [132/914] q c technologies: 0 new snapshots, 0 unchanged
# [133/914] mindwalk: 0 new snapshots, 0 unchanged
# [134/914] iterum therapeutics: 8 new snapshots, 1 unchanged
# [135/914] nexentis technologies: 0 new snapshots, 0 unchanged
# [136/914] eupraxia pharmaceuticals: 3 new snapshots, 0 unchanged
# [137/914] cortigent: 0 new snapshots, 0 unchanged
# [138/914] rockwell medical: 20 new snapshots, 0 unchanged
# [139/914] vertex pharmaceuticals: 279 new snapshots, 4 unchanged
# [140/914] first tracks biotherapeutics: 0 new snapshots, 0 unchanged
# [141/914] silo pharma: 0 new snapshots, 0 unchanged
# [142/914] hepion pharmaceuticals: 5 new snapshots, 0 unchanged
# [143/914] sagimet biosciences: 12 new snapshots, 0 unchanged
# [144/914] relay therapeutics: 6 new snapshots, 0 unchanged
# [145/914] mustang bio: 5 new snapshots, 0 unchanged
# [146/914] taysha gene therapies: 5 new snapshots, 0 unchanged
# [147/914] cellectis: 6 new snapshots, 0 unchanged
# [148/914] aditxt: 1 new snapshots, 0 unchanged
# [149/914] quoin pharmaceuticals: 4 new snapshots, 0 unchanged
# [150/914] anaptysbio: 9 new snapshots, 0 unchanged
# [151/914] sigyn therapeutics: 0 new snapshots, 0 unchanged
# [152/914] provectus biopharmaceuticals: 4 new snapshots, 1 unchanged
# [153/914] cypherpunk technologies: 0 new snapshots, 0 unchanged
# [154/914] grifols: 120 new snapshots, 0 unchanged
# [155/914] cg oncology: 8 new snapshots, 1 unchanged
# [156/914] halozyme therapeutics: 39 new snapshots, 8 unchanged
# [157/914] biolinerx: 21 new snapshots, 2 unchanged
# [158/914] icu medical: 3 new snapshots, 0 unchanged
# [159/914] lucid diagnostics: 7 new snapshots, 0 unchanged
# [160/914] clearmind medicine: 1 new snapshots, 0 unchanged
# [161/914] skye bioscience: 2 new snapshots, 0 unchanged
# [162/914] altamira therapeutics: 0 new snapshots, 0 unchanged
# [163/914] propanc biopharma: 0 new snapshots, 0 unchanged
# [164/914] earth science tech: 0 new snapshots, 0 unchanged
# [165/914] precision biosciences: 6 new snapshots, 0 unchanged
# [166/914] inhibrx biosciences: 7 new snapshots, 0 unchanged
# [167/914] decoy therapeutics: 0 new snapshots, 0 unchanged
# [168/914] viridian therapeutics: 8 new snapshots, 0 unchanged
# [169/914] nuwellis: 11 new snapshots, 0 unchanged
# [170/914] zevra therapeutics: 5 new snapshots, 0 unchanged
# [171/914] vericel: 15 new snapshots, 0 unchanged
# [172/914] ideaya biosciences: 11 new snapshots, 0 unchanged
# [173/914] leonabio: 9 new snapshots, 0 unchanged
# [174/914] lipocine: 8 new snapshots, 0 unchanged
# [175/914] cytomx therapeutics: 9 new snapshots, 0 unchanged
# [176/914] lyra therapeutics: 7 new snapshots, 0 unchanged
# [177/914] lifevantage: 1 new snapshots, 0 unchanged
# [178/914] calcimedica: 8 new snapshots, 0 unchanged
# [179/914] stoke therapeutics: 3 new snapshots, 0 unchanged
# [180/914] alpha cognition: 0 new snapshots, 0 unchanged
# [181/914] zenas biopharma: 10 new snapshots, 0 unchanged
# [182/914] tenax therapeutics: 8 new snapshots, 1 unchanged
# [183/914] sintx technologies: 0 new snapshots, 0 unchanged
# [184/914] immutep: 17 new snapshots, 0 unchanged
# [185/914] astrotech: 0 new snapshots, 0 unchanged
# [186/914] actinium pharmaceuticals: 9 new snapshots, 0 unchanged
# [187/914] gelteq: 0 new snapshots, 0 unchanged
# [188/914] cytokinetics: 45 new snapshots, 0 unchanged
# [189/914] tonix pharmaceuticals: 37 new snapshots, 0 unchanged
# [190/914] zura bio: 2 new snapshots, 0 unchanged
# [191/914] barinthus biotherapeutics: 11 new snapshots, 0 unchanged
# [192/914] orthopediatrics: 2 new snapshots, 0 unchanged
# [193/914] indaptus therapeutics: 1 new snapshots, 0 unchanged
# [194/914] atossa therapeutics: 8 new snapshots, 0 unchanged
# [195/914] madrigal pharmaceuticals: 18 new snapshots, 0 unchanged
# [196/914] profound medical: 4 new snapshots, 0 unchanged
# [197/914] corbus pharmaceuticals: 10 new snapshots, 0 unchanged
# [198/914] telomir pharmaceuticals: 1 new snapshots, 0 unchanged
# [199/914] journey medical: 12 new snapshots, 0 unchanged
# [200/914] xtant medical: 3 new snapshots, 0 unchanged
# [201/914] veradermics: 5 new snapshots, 0 unchanged
# [202/914] cocrystal pharma: 6 new snapshots, 0 unchanged
# [203/914] neuropace: 11 new snapshots, 0 unchanged
# [204/914] ultragenyx pharmaceutical: 85 new snapshots, 5 unchanged
# [205/914] creative medical technology: 3 new snapshots, 1 unchanged
# [206/914] premier air charter: 0 new snapshots, 0 unchanged
# [207/914] neuroone medical technologies: 1 new snapshots, 0 unchanged
# [208/914] iradimed: 0 new snapshots, 0 unchanged
# [209/914] gossamer bio: 13 new snapshots, 0 unchanged
# [210/914] neonc technologies: 4 new snapshots, 0 unchanged
# [211/914] kazia therapeutics: 13 new snapshots, 1 unchanged
# [212/914] processa pharmaceuticals: 10 new snapshots, 0 unchanged
# [213/914] merit medical systems: 40 new snapshots, 0 unchanged
# [214/914] tarsier pharma: 3 new snapshots, 0 unchanged
# [215/914] incyte: 450 new snapshots, 35 unchanged
# [216/914] meihua international medical technologies: 0 new snapshots, 0 unchanged
# [217/914] alpha teknova: 0 new snapshots, 0 unchanged
# [218/914] nasus pharma: 6 new snapshots, 0 unchanged
# [219/914] nervgen pharma: 2 new snapshots, 0 unchanged
# [220/914] aeon biopharma: 4 new snapshots, 0 unchanged
# [221/914] pyxis oncology: 5 new snapshots, 0 unchanged
# [222/914] teva pharmaceutical industries: 18 new snapshots, 0 unchanged
# [223/914] elite pharmaceuticals: 0 new snapshots, 0 unchanged
# [224/914] pulmatrix: 16 new snapshots, 0 unchanged
# [225/914] eloxx pharmaceuticals: 9 new snapshots, 0 unchanged
# [226/914] inspire medical systems: 16 new snapshots, 0 unchanged
# [227/914] dbv technologies: 16 new snapshots, 2 unchanged
# [228/914] aptose biosciences: 8 new snapshots, 0 unchanged
# [229/914] aclaris therapeutics: 36 new snapshots, 0 unchanged
# [230/914] johnson & johnson: 1503 new snapshots, 25 unchanged
# [231/914] tvardi therapeutics: 7 new snapshots, 0 unchanged
# [232/914] cardiol therapeutics: 4 new snapshots, 0 unchanged
# [233/914] beacon topco: 0 new snapshots, 0 unchanged
# [234/914] ocugen: 10 new snapshots, 2 unchanged
# [235/914] roivant sciences: 2 new snapshots, 0 unchanged
# [236/914] koru medical systems: 1 new snapshots, 0 unchanged
# [237/914] brainsway: 39 new snapshots, 2 unchanged
# [238/914] kura oncology: 21 new snapshots, 2 unchanged
# [239/914] aligos therapeutics: 15 new snapshots, 0 unchanged
# [240/914] accustem sciences: 0 new snapshots, 0 unchanged
# [241/914] genelux: 9 new snapshots, 1 unchanged
# [242/914] edgewise therapeutics: 18 new snapshots, 0 unchanged
# [243/914] bright minds biosciences: 3 new snapshots, 0 unchanged
# [244/914] sangamo therapeutics: 30 new snapshots, 0 unchanged
# [245/914] syndax pharmaceuticals: 50 new snapshots, 2 unchanged
# [246/914] ibio: 3 new snapshots, 0 unchanged
# [247/914] ebr systems: 7 new snapshots, 0 unchanged
# [248/914] kestra medical technologies: 3 new snapshots, 0 unchanged
# [249/914] lakeshore biopharma: 0 new snapshots, 0 unchanged
# [250/914] supernus pharmaceuticals: 77 new snapshots, 4 unchanged
# [251/914] organon: 540 new snapshots, 4 unchanged
# [252/914] biomx: 4 new snapshots, 0 unchanged
# [253/914] oncolytics biotech: 22 new snapshots, 1 unchanged
# [254/914] optex systems: 0 new snapshots, 0 unchanged
# [255/914] eton pharmaceuticals: 0 new snapshots, 0 unchanged
# [256/914] fibrobiologics: 2 new snapshots, 0 unchanged
# [257/914] protalix biotherapeutics: 0 new snapshots, 0 unchanged
# [258/914] emmaus life sciences: 0 new snapshots, 0 unchanged
# [259/914] merck: 4932 new snapshots, 218 unchanged
# [260/914] artiva biotherapeutics: 7 new snapshots, 0 unchanged
# [261/914] janux therapeutics: 4 new snapshots, 0 unchanged
# [262/914] cns pharmaceuticals: 1 new snapshots, 0 unchanged
# [263/914] biomerica: 3 new snapshots, 0 unchanged
# [264/914] adc therapeutics: 34 new snapshots, 1 unchanged
# [265/914] west pharmaceutical services: 0 new snapshots, 0 unchanged
# [266/914] anixa biosciences: 2 new snapshots, 0 unchanged
# [267/914] io biotech: 4 new snapshots, 5 unchanged
# [268/914] adaptin bio: 1 new snapshots, 0 unchanged
# [269/914] disc medicine: 10 new snapshots, 0 unchanged
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\chris\AppData\Local\Temp/ipykernel_29648/3595948952.py", line 14, in <module>
#     run()
#   File "C:\Users\chris\Documents\personal_projects\market_research\pipeline.py", line 56, in run
#     trials = fetch_trials(search_name)
#   File "C:\Users\chris\Documents\personal_projects\market_research\scraper.py", line 111, in fetch_trials
#     response = requests.get(base_url, params=params)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py", line 644, in send
#     resp = conn.urlopen(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py", line 416, in connect
#     self.sock = ssl_wrap_socket(
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\ssl_.py", line 402, in ssl_wrap_socket
#     context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp/ipykernel_29648/3595948952.py in <module>
#      13
# ---> 14 run()
#      15 #run_landscape(conditions)
#
# ~\Documents\personal_projects\market_research\pipeline.py in run()
#      55         search_name = sponsor_aliases.get(company, company)
# ---> 56         trials = fetch_trials(search_name)
#      57
#
# ~\Documents\personal_projects\market_research\scraper.py in fetch_trials(company_name)
#     110
# --> 111         response = requests.get(base_url, params=params)
#     112         response.raise_for_status()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     643         try:
# --> 644             resp = conn.urlopen(
#     645                 method=request.method,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py in connect(self)
#     415
# --> 416         self.sock = ssl_wrap_socket(
#     417             sock=conn,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         # in the engines. This should return a list of strings.
# -> 2064                         stb = value._render_traceback_()
#    2065                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2064                         stb = value._render_traceback_()
#    2065                     except Exception:
# -> 2066                         stb = self.InteractiveTB.structured_traceback(etype,
#    2067                                             value, tb, tb_offset=tb_offset)
#    2068
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
