# %%
from pipeline import run, run_landscape
import os

main_dir = 'C:\\Users\\chris\\Documents\\personal_projects\\market_research'
save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

#conditions = [
#        "ST Elevation Myocardial Infarction"
#    ]


run()
#run_landscape(conditions)
# Out:
# SIC 2836: 489 companies
# SIC 2835: 151 companies
# SIC 2834: 1892 companies
# SIC 8731: 181 companies
# Warning: failed fetching SIC 3841 at start=0: HTTPSConnectionPool(host='www.sec.gov', port=443): Read timed out. (read timeout=15)
# SIC 3841: 0 companies
# SIC 3845: 260 companies
# SIC 3826: 108 companies
# SIC 3827: 43 companies
# Total unique CIKs: 3124
# SEC universe: 776 companies with valid tickers
# [1/784] cogent biosciences: 0 new snapshots, 15 unchanged
# [2/784] mbx biosciences: 0 new snapshots, 7 unchanged
# [3/784] century therapeutics: 0 new snapshots, 3 unchanged
# [4/784] compass therapeutics: 0 new snapshots, 8 unchanged
# [5/784] cue biopharma: 0 new snapshots, 5 unchanged
# [6/784] odyssey therapeutics: 0 new snapshots, 2 unchanged
# [7/784] kala bio: 0 new snapshots, 0 unchanged
# [8/784] barinthus biotherapeutics: 0 new snapshots, 11 unchanged
# [9/784] puma biotechnology: 0 new snapshots, 59 unchanged
# [10/784] assertio: 0 new snapshots, 2 unchanged
# [11/784] travere therapeutics: 0 new snapshots, 19 unchanged
# [12/784] mink therapeutics: 0 new snapshots, 3 unchanged
# [13/784] perrigo: 0 new snapshots, 19 unchanged
# [14/784] sarepta therapeutics: 0 new snapshots, 57 unchanged
# [15/784] geron: 0 new snapshots, 24 unchanged
# [16/784] crescent biopharma: 0 new snapshots, 1 unchanged
# [17/784] igc pharma: 0 new snapshots, 2 unchanged
# [18/784] supernus pharmaceuticals: 0 new snapshots, 81 unchanged
# [19/784] outset medical: 0 new snapshots, 6 unchanged
# [20/784] corvus pharmaceuticals: 0 new snapshots, 10 unchanged
# [21/784] one world products: 0 new snapshots, 0 unchanged
# [22/784] diamedica therapeutics: 0 new snapshots, 7 unchanged
# [23/784] zevra therapeutics: 0 new snapshots, 5 unchanged
# [24/784] biontech: 0 new snapshots, 117 unchanged
# [25/784] alterity therapeutics: 0 new snapshots, 3 unchanged
# [26/784] maze therapeutics: 0 new snapshots, 2 unchanged
# [27/784] quanterix: 0 new snapshots, 0 unchanged
# [28/784] karyopharm therapeutics: 0 new snapshots, 94 unchanged
# [29/784] veraxa biotech: 0 new snapshots, 0 unchanged
# [30/784] korro bio: 0 new snapshots, 1 unchanged
# [31/784] biomx: 0 new snapshots, 4 unchanged
# [32/784] pyrogenesis canada: 0 new snapshots, 0 unchanged
# [33/784] longeveron: 0 new snapshots, 10 unchanged
# [34/784] pharmacyte biotech: 0 new snapshots, 0 unchanged
# [35/784] ocean biomedical: 0 new snapshots, 3 unchanged
# [36/784] altimmune: 0 new snapshots, 19 unchanged
# [37/784] promis neurosciences: 0 new snapshots, 2 unchanged
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30124/3595948952.py in <module>
#      12
#      13
# ---> 14 run()
#      15 #run_landscape(conditions)
#
# ~\Documents\personal_projects\market_research\pipeline.py in run()
#      64         company = clean_name(c['name'])
#      65         search_name = sponsor_aliases.get(company, company)
# ---> 66         trials = fetch_trials(search_name)
#      67
#      68         for trial in trials:
#
# ~\Documents\personal_projects\market_research\scraper.py in fetch_trials(company_name)
#     109             params['pageToken'] = next_token
#     110
# --> 111         response = requests.get(base_url, params=params)
#     112         response.raise_for_status()
#     113         data = response.json()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     642
#     643         try:
# --> 644             resp = conn.urlopen(
#     645                 method=request.method,
#     646                 url=url,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py in connect(self)
#     414             context.load_default_certs()
#     415
# --> 416         self.sock = ssl_wrap_socket(
#     417             sock=conn,
#     418             keyfile=self.key_file,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     447
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#     451         )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     491
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#     495         return ssl_context.wrap_socket(sock)
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:
