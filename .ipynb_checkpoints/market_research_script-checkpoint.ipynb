# %%
from pipeline import run, run_landscape
import os

main_dir = 'C:\\Users\\chris\\Documents\\personal_projects\\market_research'
save_dir = 'C:\\Users\\chris\Documents\\personal_projects'

os.chdir(save_dir)

#conditions = [
#        "ST Elevation Myocardial Infarction"
#    ]


run()
#run_landscape(conditions)
# Out:
# [1/268] revolution medicines: 0 new snapshots, 1 unchanged
# [2/268] travere therapeutics: 0 new snapshots, 0 unchanged
# [3/268] tg therapeutics: 0 new snapshots, 0 unchanged
# [4/268] alkermes: 0 new snapshots, 1 unchanged
# [5/268] arrowhead pharmaceuticals: 0 new snapshots, 1 unchanged
# [6/268] madrigal pharmaceuticals: 0 new snapshots, 0 unchanged
# [7/268] krystal biotech: 0 new snapshots, 0 unchanged
# [8/268] cytokinetics: 0 new snapshots, 0 unchanged
# [9/268] neurocrine biosciences: 0 new snapshots, 2 unchanged
# [10/268] exelixis: 0 new snapshots, 3 unchanged
# [11/268] mirum pharmaceuticals: 0 new snapshots, 1 unchanged
# [12/268] scholar rock: 0 new snapshots, 1 unchanged
# [13/268] celcuity: 0 new snapshots, 1 unchanged
# [14/268] praxis precision medicines: 0 new snapshots, 0 unchanged
# [15/268] beam therapeutics: 0 new snapshots, 0 unchanged
# [16/268] twist bioscience: 0 new snapshots, 0 unchanged
# [17/268] apogee therapeutics: 0 new snapshots, 0 unchanged
# [18/268] ptc therapeutics: 0 new snapshots, 3 unchanged
# [19/268] protagonist therapeutics: 0 new snapshots, 0 unchanged
# [20/268] united therapeutics: 0 new snapshots, 1 unchanged
# [21/268] cg oncology: 0 new snapshots, 1 unchanged
# [22/268] nuvalent: 0 new snapshots, 2 unchanged
# [23/268] summit therapeutics: 0 new snapshots, 0 unchanged
# [24/268] halozyme therapeutics: 0 new snapshots, 0 unchanged
# [25/268] rhythm pharmaceuticals: 0 new snapshots, 1 unchanged
# [26/268] kymera therapeutics: 0 new snapshots, 0 unchanged
# [27/268] incyte: 0 new snapshots, 12 unchanged
# [28/268] ionis pharmaceuticals: 0 new snapshots, 10 unchanged
# [29/268] crispr therapeutics: 0 new snapshots, 0 unchanged
# [30/268] biogen: 0 new snapshots, 5 unchanged
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23120/3595948952.py in <module>
#      12
#      13
# ---> 14 run()
#      15 #run_landscape(conditions)
#
# ~\Documents\personal_projects\market_research\pipeline.py in run()
#      27             trial['company'] = ticker if ticker else sponsor
#      28
# ---> 29         inserted, skipped = insert_trials(trials, company)
#      30         total_inserted += inserted
#      31         total_skipped += skipped
#
# ~\Documents\personal_projects\market_research\db.py in insert_trials(trials, company)
#     117             continue
#     118
# --> 119         cur.execute("""
#     120         INSERT INTO trials (nct_id, company, sponsor, title, phase, fda_regulated, status,
#     121                     study_type, conditions, interventions, enrollment, start_date,
#
# OperationalError: 18 values for 17 columns
