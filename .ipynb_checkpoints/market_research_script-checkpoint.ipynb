# %%
from pipeline import run

run()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11704/2444268869.py in <module>
#       1 from pipeline import run
#       2
# ----> 3 run()
#
# ~\Documents\personal_projects\market_research\pipeline.py in run()
#      27             for company in companies:
#      28                 trials = fetch_trials(company)
# ---> 29                 insert_trials(trials, company)
#      30                 trial['company'] = ticker if ticker else sponsor
#      31
#
# ~\Documents\personal_projects\market_research\db.py in insert_trials(trials, company)
#      49     for t in trials:
#      50
# ---> 51         cur.execute("""
#      52         INSERT INTO trials VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
#      53         """, (
#
# OperationalError: table trials has 15 columns but 16 values were supplied
