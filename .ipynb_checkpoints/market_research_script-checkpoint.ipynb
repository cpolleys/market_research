# %%
from pipeline import run
import os

os.getcwd()

#run()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10816/2444268869.py in <module>
#       1 from pipeline import run
#       2
# ----> 3 run()
#
# ~\Documents\personal_projects\market_research\pipeline.py in run()
#      12 def run():
#      13     init_db()
# ---> 14     mappings = load_mappings()
#      15
#      16     for company in COMPANIES:
#
# ~\Documents\personal_projects\market_research\mappings.py in load_mappings()
#       2
#       3 def load_mappings():
# ----> 4     with open('mappings.json') as f:
#       5         return json.load(f)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mappings.json'
